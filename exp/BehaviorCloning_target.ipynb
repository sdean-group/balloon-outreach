# %% [markdown]
# # Behavior Cloning
#
# ## Objective: Fly balloon to the target.
#
#
# 0. You should **download** your ERA5 wind field data from the following link:
# https://drive.google.com/file/d/1Y5ocrCH0TVf9ZDkVGaJ03ftUrtKEVxIf/view?usp=sharing
# - Download the data and save it into your Google Drive.
#
# 1.Imitation learning is a paradigm where an agent learns to mimic an **expert's behavior** instead of learning purely from trial-and-error rewards (e.g., reinforcement learning).
#
# - The simplest common approach is called "**behavior cloning**" (BC). It treats the expert's demonstrations as training data samples; train a policy using the expert's input(state) and output(action) pairs via supervised learning.

# %%
# The following lines are needed when using Windows 
# An error regarding this happens when the program is trying to initialize multiple versions of the libiomp5md.dll library (the Intel OpenMP runtime), which leads to conflicts. 
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

import sys
sys.path.append("C:\\Users\\sc3377\\Documents\\balloon-outreach")

# %%
import xarray as xr
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import time

from env.balloon_env import BalloonERAEnvironment
from agent.mppi_agent import MPPIAgentWithCostFunction, MPPIAgent
from exp.learning_util import plot_agent_trajectory, plot_expert_summary
from env.util import haversine_distance

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

# %% [markdown]
# ## Setup Environment

# %%
datapath = "C:\\Users\\sc3377\\Documents\\balloon-outreach\\era5_data.nc"

# %%
ds          = xr.open_dataset(datapath, engine="netcdf4")
start_time  = dt.datetime(year=2024, month=7, day=1, hour=0, minute=0)


#This is Ithaca
initial_lat = 42.6
initial_lon = -76.5
initial_alt = 10.0

target_lat = 77.3
target_lon = -80.5
target_alt = 12.0

time_step = 120 #120 seconds
objective = 'target'

env = BalloonERAEnvironment(ds=ds,
                            start_time=start_time,
                            initial_lat=initial_lat,
                            initial_lon=initial_lon,
                            initial_alt=initial_alt,
                            target_lat=target_lat,
                            target_lon=target_lon,
                            target_alt=target_alt,
                            objective=objective,
                            dt=time_step,
                            viz=False)
# Out:
# WindField initialized with noise enabled: True

# %%
env.wind_field.disable_noise()
initial_state = env.reset()
print(initial_state) # 21-dimensional vector

# state = (latitude, longitude, altitude, volume/max_volume, sand/max_sand,
# vertical velocity, current_time, uv vectors in 7 different pressure levels)
# Out:
# [ 42.6        -76.5         10.           1.           1.
#    0.           0.           2.68826294  -2.50693054  11.1584198
#   -7.97099304  14.01635132  -5.00876465  27.14085999   3.41699524
#   34.82033386  14.09255371  38.58664856   7.6340332   18.78843994
#   -4.25058899]

# %% [markdown]
# ## Define expert policy

# %%
# Parameters for MPPI agent

max_steps = int(1440/(time_step/60)) #1 day

num_samples=10
acc_bounds= (-0.1, 0.1)
noise_std = 0.1
num_iterations=1

# For target
horizon=10

# For fly
# horizon = 5

# %%
expert = MPPIAgentWithCostFunction(target_lat=target_lat,
                                   target_lon=target_lon,
                                   target_alt=target_alt,
                                   num_samples=num_samples,
                                   acc_bounds= acc_bounds,
                                   noise_std=noise_std,
                                   num_iterations=num_iterations,
                                   horizon=horizon,
                                   visualize=False,
                                   objective=objective)

# %% [markdown]
# ## Collect expert state-action pair

# %%
# Run an episode from an expert and collect its behavior

def run_expert_episode(
        env: BalloonERAEnvironment,
        agent:MPPIAgent,
        max_steps: int = 100,
        policy_name: str='expert'):
    """
    Run one episode with the given agent,
    collect state-action pair of the agent,
    and plot its trajectory in the given environment.
    """
    # Save state-action pairs from expert policy
    initial_states = []
    initial_actions = []

    state = env.reset()
    total_reward = 0

    # Store trajectory for plotting
    trajectory = [(state[0], state[1])]  # (lat, lon) pairs
    altitudes = [state[2]]  # Store altitudes

    actions = []
    velocities = []
    helium_mass = []
    sands = []
    for step in range(max_steps):
        # Get action from agent
        action = agent.select_action(state, env, step)

        # record state and expert action
        initial_states.append(state)
        initial_actions.append(action)

        # Take step
        state, reward, done, info = env.step(action)
        total_reward += reward

        actions.append(float(action[0]) if isinstance(action, np.ndarray) else float(action))
        velocities.append(env.balloon.vertical_velocity)
        helium_mass.append(env.balloon.helium_mass)
        sands.append(env.balloon.sand)

        # Store position and altitude
        trajectory.append((state[0], state[1]))
        altitudes.append(state[2])
        print(f"Step {step}: lat: {state[0]:.2f}, lon: {state[1]:.2f}, alt: {state[2]:.2f}")
        # env.render()

        if done:
            print(f"\nEpisode terminated: {info}")
            break

    # Convert to arrays
    states_np = np.array(initial_states, dtype=np.float32)
    actions_np = np.array(initial_actions, dtype=np.float32)
    print(f"Collected {len(initial_states)} state-action pairs from expert.")

    # --- Combined 2x2 Summary Plot ---
    plot_expert_summary(agent, trajectory, altitudes, actions, velocities, helium_mass, sands, policy_name, max_steps, time_step)

    return total_reward, states_np, actions_np

# %%
env.wind_field.disable_noise()
# env.wind_field.enable_noise(noise_seed=10) # If you want to enable noisy wind field
expert_total_reward_list = []
expert_states_list = []
expert_actions_list = []
num_iter = 3
for i in range(num_iter):
    expert_total_reward, expert_states_np, expert_actions_np = run_expert_episode(env, expert, max_steps=max_steps, policy_name=f'expert_{i+1}')
    expert_total_reward_list.append(expert_total_reward)
    expert_states_list.append(expert_states_np)
    expert_actions_list.append(expert_actions_np)
# Out:
# Step 0: lat: 42.78, lon: -76.49, alt: 9.89
# Step 1: lat: 42.95, lon: -76.48, alt: 9.80
# Step 2: lat: 43.13, lon: -76.47, alt: 9.69
# Step 3: lat: 43.31, lon: -76.46, alt: 9.58
# Step 4: lat: 43.49, lon: -76.45, alt: 9.46
# Step 5: lat: 43.67, lon: -76.43, alt: 9.34
# Step 6: lat: 43.86, lon: -76.42, alt: 9.22
# Step 7: lat: 44.04, lon: -76.41, alt: 9.10
# Step 8: lat: 44.23, lon: -76.39, alt: 8.98
# Step 9: lat: 44.41, lon: -76.37, alt: 8.86
# Step 10: lat: 44.60, lon: -76.36, alt: 8.75
# Step 11: lat: 44.78, lon: -76.34, alt: 8.63
# Step 12: lat: 44.96, lon: -76.32, alt: 8.53
# Step 13: lat: 45.14, lon: -76.31, alt: 8.44
# Step 14: lat: 45.31, lon: -76.29, alt: 8.36
# Step 15: lat: 45.47, lon: -76.27, alt: 8.29
# Step 16: lat: 45.62, lon: -76.26, alt: 8.23
# Step 17: lat: 45.75, lon: -76.25, alt: 8.18
# Step 18: lat: 45.87, lon: -76.24, alt: 8.14
# Step 19: lat: 45.99, lon: -76.23, alt: 8.11
# Step 20: lat: 46.09, lon: -76.22, alt: 8.09
# Step 21: lat: 46.19, lon: -76.22, alt: 8.08
# Step 22: lat: 46.28, lon: -76.21, alt: 8.08
# Step 23: lat: 46.36, lon: -76.20, alt: 8.09
# Step 24: lat: 46.43, lon: -76.20, alt: 8.11
# Step 25: lat: 46.51, lon: -76.20, alt: 8.15
# Step 26: lat: 46.57, lon: -76.19, alt: 8.19
# Step 27: lat: 46.64, lon: -76.19, alt: 8.25
# Step 28: lat: 46.70, lon: -76.19, alt: 8.31
# Step 29: lat: 46.76, lon: -76.18, alt: 8.39
# Step 30: lat: 46.81, lon: -76.18, alt: 8.48
# Step 31: lat: 46.87, lon: -76.18, alt: 8.57
# Step 32: lat: 46.92, lon: -76.17, alt: 8.68
# Step 33: lat: 46.98, lon: -76.17, alt: 8.80
# Step 34: lat: 47.04, lon: -76.17, alt: 8.92
# Step 35: lat: 47.09, lon: -76.17, alt: 9.04
# Step 36: lat: 47.15, lon: -76.17, alt: 9.16
# Step 37: lat: 47.22, lon: -76.16, alt: 9.28
# Step 38: lat: 47.28, lon: -76.16, alt: 9.40
# Step 39: lat: 47.34, lon: -76.16, alt: 9.52
# Step 40: lat: 47.41, lon: -76.16, alt: 9.64
# Step 41: lat: 47.48, lon: -76.16, alt: 9.76
# Step 42: lat: 47.55, lon: -76.16, alt: 9.88
# Step 43: lat: 47.62, lon: -76.16, alt: 10.00
# Step 44: lat: 47.70, lon: -76.16, alt: 10.12
# Step 45: lat: 47.77, lon: -76.16, alt: 10.24
# Step 46: lat: 47.85, lon: -76.16, alt: 10.36
# Step 47: lat: 47.93, lon: -76.16, alt: 10.48
# Step 48: lat: 48.00, lon: -76.16, alt: 10.60
# Step 49: lat: 48.08, lon: -76.16, alt: 10.72
# Step 50: lat: 48.15, lon: -76.16, alt: 10.84
# Step 51: lat: 48.23, lon: -76.16, alt: 10.96
# Step 52: lat: 48.30, lon: -76.16, alt: 11.08
# Step 53: lat: 48.37, lon: -76.16, alt: 11.20
# Step 54: lat: 48.44, lon: -76.16, alt: 11.32
# Step 55: lat: 48.51, lon: -76.16, alt: 11.43
# Step 56: lat: 48.58, lon: -76.16, alt: 11.55
# Step 57: lat: 48.65, lon: -76.16, alt: 11.67
# Step 58: lat: 48.72, lon: -76.17, alt: 11.79
# Step 59: lat: 48.79, lon: -76.17, alt: 11.91
# Step 60: lat: 48.85, lon: -76.17, alt: 12.03
# Step 61: lat: 48.92, lon: -76.17, alt: 12.15
# Step 62: lat: 48.99, lon: -76.17, alt: 12.27
# Step 63: lat: 49.05, lon: -76.17, alt: 12.39
# Step 64: lat: 49.12, lon: -76.18, alt: 12.51
# Step 65: lat: 49.19, lon: -76.18, alt: 12.63
# Step 66: lat: 49.25, lon: -76.18, alt: 12.75
# Step 67: lat: 49.32, lon: -76.18, alt: 12.87
# Step 68: lat: 49.39, lon: -76.18, alt: 12.99
# Step 69: lat: 49.45, lon: -76.19, alt: 13.11
# Step 70: lat: 49.52, lon: -76.19, alt: 13.23
# Step 71: lat: 49.59, lon: -76.19, alt: 13.35
# Step 72: lat: 49.66, lon: -76.19, alt: 13.47
# Step 73: lat: 49.73, lon: -76.19, alt: 13.58
# Step 74: lat: 49.80, lon: -76.20, alt: 13.70
# Step 75: lat: 49.87, lon: -76.20, alt: 13.82
# Step 76: lat: 49.94, lon: -76.20, alt: 13.94
# Step 77: lat: 50.01, lon: -76.20, alt: 14.06
# Step 78: lat: 50.08, lon: -76.20, alt: 14.18
# Step 79: lat: 50.15, lon: -76.21, alt: 14.30
# Step 80: lat: 50.22, lon: -76.21, alt: 14.42
# Step 81: lat: 50.30, lon: -76.21, alt: 14.54
# Step 82: lat: 50.37, lon: -76.21, alt: 14.66
# Step 83: lat: 50.44, lon: -76.21, alt: 14.78
# Step 84: lat: 50.52, lon: -76.21, alt: 14.90
# Step 85: lat: 50.59, lon: -76.21, alt: 15.02
# Step 86: lat: 50.66, lon: -76.21, alt: 15.14
# Step 87: lat: 50.74, lon: -76.21, alt: 15.26
# Step 88: lat: 50.81, lon: -76.21, alt: 15.38
# Step 89: lat: 50.88, lon: -76.21, alt: 15.50
# Step 90: lat: 50.95, lon: -76.21, alt: 15.62
# Step 91: lat: 51.02, lon: -76.21, alt: 15.74
# Step 92: lat: 51.09, lon: -76.20, alt: 15.86
# Step 93: lat: 51.16, lon: -76.20, alt: 15.98
# Step 94: lat: 51.23, lon: -76.20, alt: 16.10
# Step 95: lat: 51.29, lon: -76.20, alt: 16.22
# Step 96: lat: 51.36, lon: -76.20, alt: 16.34
# Step 97: lat: 51.43, lon: -76.20, alt: 16.46
# Step 98: lat: 51.49, lon: -76.19, alt: 16.57
# Step 99: lat: 51.55, lon: -76.19, alt: 16.69
# Step 100: lat: 51.62, lon: -76.19, alt: 16.81
# Step 101: lat: 51.68, lon: -76.19, alt: 16.92
# Step 102: lat: 51.74, lon: -76.19, alt: 17.03
# Step 103: lat: 51.80, lon: -76.18, alt: 17.13
# Step 104: lat: 51.86, lon: -76.18, alt: 17.23
# Step 105: lat: 51.92, lon: -76.18, alt: 17.32
# Step 106: lat: 51.98, lon: -76.18, alt: 17.40
# Step 107: lat: 52.04, lon: -76.18, alt: 17.47
# Step 108: lat: 52.10, lon: -76.17, alt: 17.53
# Step 109: lat: 52.15, lon: -76.17, alt: 17.58
# Step 110: lat: 52.21, lon: -76.17, alt: 17.63
# Step 111: lat: 52.27, lon: -76.17, alt: 17.67
# Step 112: lat: 52.32, lon: -76.17, alt: 17.71
# Step 113: lat: 52.38, lon: -76.17, alt: 17.73
# Step 114: lat: 52.43, lon: -76.16, alt: 17.75
# Step 115: lat: 52.49, lon: -76.16, alt: 17.76
# Step 116: lat: 52.54, lon: -76.16, alt: 17.77
# Step 117: lat: 52.59, lon: -76.16, alt: 17.78
# Step 118: lat: 52.64, lon: -76.16, alt: 17.78
# Step 119: lat: 52.69, lon: -76.15, alt: 17.78
# Step 120: lat: 52.75, lon: -76.15, alt: 17.77
# Step 121: lat: 52.80, lon: -76.15, alt: 17.76
# Step 122: lat: 52.85, lon: -76.15, alt: 17.75
# Step 123: lat: 52.89, lon: -76.14, alt: 17.72
# Step 124: lat: 52.94, lon: -76.14, alt: 17.70
# Step 125: lat: 52.99, lon: -76.14, alt: 17.67
# Step 126: lat: 53.04, lon: -76.13, alt: 17.63
# Step 127: lat: 53.09, lon: -76.13, alt: 17.59
# Step 128: lat: 53.13, lon: -76.13, alt: 17.53
# Step 129: lat: 53.18, lon: -76.13, alt: 17.47
# Step 130: lat: 53.23, lon: -76.12, alt: 17.40
# Step 131: lat: 53.27, lon: -76.12, alt: 17.32
# Step 132: lat: 53.32, lon: -76.11, alt: 17.23
# Step 133: lat: 53.37, lon: -76.11, alt: 17.14
# Step 134: lat: 53.41, lon: -76.11, alt: 17.04
# Step 135: lat: 53.46, lon: -76.10, alt: 16.92
# Step 136: lat: 53.51, lon: -76.10, alt: 16.80
# Step 137: lat: 53.55, lon: -76.10, alt: 16.68
# Step 138: lat: 53.60, lon: -76.09, alt: 16.56
# Step 139: lat: 53.64, lon: -76.09, alt: 16.44
# Step 140: lat: 53.69, lon: -76.09, alt: 16.32
# Step 141: lat: 53.74, lon: -76.08, alt: 16.20
# Step 142: lat: 53.78, lon: -76.08, alt: 16.08
# Step 143: lat: 53.83, lon: -76.08, alt: 15.96
# Step 144: lat: 53.88, lon: -76.07, alt: 15.84
# Step 145: lat: 53.92, lon: -76.07, alt: 15.72
# Step 146: lat: 53.97, lon: -76.07, alt: 15.60
# Step 147: lat: 54.02, lon: -76.06, alt: 15.48
# Step 148: lat: 54.07, lon: -76.06, alt: 15.36
# Step 149: lat: 54.12, lon: -76.06, alt: 15.24
# Step 150: lat: 54.17, lon: -76.06, alt: 15.12
# Step 151: lat: 54.21, lon: -76.05, alt: 15.00
# Step 152: lat: 54.26, lon: -76.05, alt: 14.88
# Step 153: lat: 54.31, lon: -76.05, alt: 14.76
# Step 154: lat: 54.36, lon: -76.05, alt: 14.64
# Step 155: lat: 54.41, lon: -76.05, alt: 14.52
# Step 156: lat: 54.46, lon: -76.05, alt: 14.40
# Step 157: lat: 54.51, lon: -76.05, alt: 14.28
# Step 158: lat: 54.56, lon: -76.05, alt: 14.16
# Step 159: lat: 54.62, lon: -76.05, alt: 14.04
# Step 160: lat: 54.67, lon: -76.05, alt: 13.92
# Step 161: lat: 54.72, lon: -76.05, alt: 13.80
# Step 162: lat: 54.77, lon: -76.05, alt: 13.68
# Step 163: lat: 54.83, lon: -76.05, alt: 13.56
# Step 164: lat: 54.88, lon: -76.05, alt: 13.44
# Step 165: lat: 54.94, lon: -76.06, alt: 13.32
# Step 166: lat: 54.99, lon: -76.06, alt: 13.20
# Step 167: lat: 55.05, lon: -76.06, alt: 13.08
# Step 168: lat: 55.10, lon: -76.07, alt: 12.96
# Step 169: lat: 55.16, lon: -76.07, alt: 12.84
# Step 170: lat: 55.22, lon: -76.08, alt: 12.72
# Step 171: lat: 55.28, lon: -76.08, alt: 12.60
# Step 172: lat: 55.34, lon: -76.09, alt: 12.48
# Step 173: lat: 55.39, lon: -76.10, alt: 12.36
# Step 174: lat: 55.46, lon: -76.10, alt: 12.24
# Step 175: lat: 55.52, lon: -76.11, alt: 12.12
# Step 176: lat: 55.58, lon: -76.12, alt: 12.00
# Step 177: lat: 55.64, lon: -76.13, alt: 11.88
# Step 178: lat: 55.71, lon: -76.14, alt: 11.76
# Step 179: lat: 55.77, lon: -76.14, alt: 11.64
# Step 180: lat: 55.84, lon: -76.15, alt: 11.52
# Step 181: lat: 55.90, lon: -76.16, alt: 11.40
# Step 182: lat: 55.97, lon: -76.18, alt: 11.28
# Step 183: lat: 56.04, lon: -76.19, alt: 11.16
# Step 184: lat: 56.11, lon: -76.20, alt: 11.04
# Step 185: lat: 56.18, lon: -76.21, alt: 10.92
# Step 186: lat: 56.25, lon: -76.22, alt: 10.80
# Step 187: lat: 56.32, lon: -76.24, alt: 10.68
# Step 188: lat: 56.39, lon: -76.25, alt: 10.56
# Step 189: lat: 56.47, lon: -76.27, alt: 10.44
# Step 190: lat: 56.54, lon: -76.28, alt: 10.32
# Step 191: lat: 56.62, lon: -76.30, alt: 10.21
# Step 192: lat: 56.69, lon: -76.31, alt: 10.09
# Step 193: lat: 56.77, lon: -76.33, alt: 9.97
# Step 194: lat: 56.84, lon: -76.34, alt: 9.85
# Step 195: lat: 56.92, lon: -76.36, alt: 9.73
# Step 196: lat: 57.00, lon: -76.38, alt: 9.61
# Step 197: lat: 57.07, lon: -76.39, alt: 9.49
# Step 198: lat: 57.15, lon: -76.41, alt: 9.37
# Step 199: lat: 57.23, lon: -76.43, alt: 9.25
# Step 200: lat: 57.30, lon: -76.45, alt: 9.13
# Step 201: lat: 57.38, lon: -76.47, alt: 9.01
# Step 202: lat: 57.46, lon: -76.49, alt: 8.89
# Step 203: lat: 57.54, lon: -76.51, alt: 8.77
# Step 204: lat: 57.62, lon: -76.53, alt: 8.67
# Step 205: lat: 57.70, lon: -76.55, alt: 8.57
# Step 206: lat: 57.79, lon: -76.57, alt: 8.49
# Step 207: lat: 57.87, lon: -76.59, alt: 8.41
# Step 208: lat: 57.96, lon: -76.61, alt: 8.33
# Step 209: lat: 58.04, lon: -76.63, alt: 8.27
# Step 210: lat: 58.13, lon: -76.65, alt: 8.21
# Step 211: lat: 58.22, lon: -76.68, alt: 8.16
# Step 212: lat: 58.30, lon: -76.70, alt: 8.12
# Step 213: lat: 58.39, lon: -76.72, alt: 8.09
# Step 214: lat: 58.48, lon: -76.74, alt: 8.07
# Step 215: lat: 58.57, lon: -76.77, alt: 8.06
# Step 216: lat: 58.66, lon: -76.79, alt: 8.05
# Step 217: lat: 58.75, lon: -76.81, alt: 8.05
# Step 218: lat: 58.84, lon: -76.84, alt: 8.06
# Step 219: lat: 58.94, lon: -76.86, alt: 8.06
# Step 220: lat: 59.03, lon: -76.88, alt: 8.08
# Step 221: lat: 59.12, lon: -76.91, alt: 8.10
# Step 222: lat: 59.21, lon: -76.93, alt: 8.11
# Step 223: lat: 59.31, lon: -76.96, alt: 8.13
# Step 224: lat: 59.40, lon: -76.98, alt: 8.14
# Step 225: lat: 59.49, lon: -77.01, alt: 8.15
# Step 226: lat: 59.59, lon: -77.04, alt: 8.15
# Step 227: lat: 59.68, lon: -77.06, alt: 8.15
# Step 228: lat: 59.78, lon: -77.09, alt: 8.15
# Step 229: lat: 59.88, lon: -77.12, alt: 8.16
# Step 230: lat: 59.97, lon: -77.15, alt: 8.17
# Step 231: lat: 60.07, lon: -77.18, alt: 8.18
# Step 232: lat: 60.16, lon: -77.20, alt: 8.19
# Step 233: lat: 60.26, lon: -77.23, alt: 8.19
# Step 234: lat: 60.36, lon: -77.26, alt: 8.20
# Step 235: lat: 60.46, lon: -77.29, alt: 8.22
# Step 236: lat: 60.55, lon: -77.32, alt: 8.23
# Step 237: lat: 60.65, lon: -77.35, alt: 8.25
# Step 238: lat: 60.75, lon: -77.38, alt: 8.27
# Step 239: lat: 60.84, lon: -77.42, alt: 8.29
# Step 240: lat: 60.94, lon: -77.45, alt: 8.30
# Step 241: lat: 61.04, lon: -77.48, alt: 8.31
# Step 242: lat: 61.13, lon: -77.51, alt: 8.31
# Step 243: lat: 61.23, lon: -77.54, alt: 8.31
# Step 244: lat: 61.33, lon: -77.57, alt: 8.31
# Step 245: lat: 61.42, lon: -77.60, alt: 8.31
# Step 246: lat: 61.52, lon: -77.64, alt: 8.31
# Step 247: lat: 61.62, lon: -77.67, alt: 8.32
# Step 248: lat: 61.71, lon: -77.70, alt: 8.32
# Step 249: lat: 61.81, lon: -77.73, alt: 8.32
# Step 250: lat: 61.91, lon: -77.77, alt: 8.31
# Step 251: lat: 62.00, lon: -77.80, alt: 8.30
# Step 252: lat: 62.10, lon: -77.83, alt: 8.30
# Step 253: lat: 62.19, lon: -77.86, alt: 8.31
# Step 254: lat: 62.29, lon: -77.90, alt: 8.31
# Step 255: lat: 62.38, lon: -77.93, alt: 8.31
# Step 256: lat: 62.47, lon: -77.96, alt: 8.31
# Step 257: lat: 62.57, lon: -77.99, alt: 8.31
# Step 258: lat: 62.66, lon: -78.03, alt: 8.31
# Step 259: lat: 62.76, lon: -78.06, alt: 8.32
# Step 260: lat: 62.85, lon: -78.09, alt: 8.32
# Step 261: lat: 62.95, lon: -78.12, alt: 8.32
# Step 262: lat: 63.04, lon: -78.16, alt: 8.33
# Step 263: lat: 63.14, lon: -78.19, alt: 8.34
# Step 264: lat: 63.23, lon: -78.22, alt: 8.33
# Step 265: lat: 63.33, lon: -78.26, alt: 8.32
# Step 266: lat: 63.43, lon: -78.29, alt: 8.31
# Step 267: lat: 63.53, lon: -78.32, alt: 8.31
# Step 268: lat: 63.63, lon: -78.35, alt: 8.31
# Step 269: lat: 63.73, lon: -78.39, alt: 8.32
# Step 270: lat: 63.83, lon: -78.42, alt: 8.33
# Step 271: lat: 63.93, lon: -78.45, alt: 8.33
# Step 272: lat: 64.03, lon: -78.49, alt: 8.33
# Step 273: lat: 64.14, lon: -78.52, alt: 8.33
# Step 274: lat: 64.24, lon: -78.55, alt: 8.33
# Step 275: lat: 64.35, lon: -78.59, alt: 8.34
# Step 276: lat: 64.45, lon: -78.62, alt: 8.35
# Step 277: lat: 64.56, lon: -78.65, alt: 8.35
# Step 278: lat: 64.66, lon: -78.69, alt: 8.34
# Step 279: lat: 64.76, lon: -78.72, alt: 8.33
# Step 280: lat: 64.86, lon: -78.75, alt: 8.33
# Step 281: lat: 64.97, lon: -78.79, alt: 8.32
# Step 282: lat: 65.06, lon: -78.82, alt: 8.32
# Step 283: lat: 65.16, lon: -78.85, alt: 8.32
# Step 284: lat: 65.26, lon: -78.89, alt: 8.33
# Step 285: lat: 65.35, lon: -78.92, alt: 8.33
# Step 286: lat: 65.44, lon: -78.95, alt: 8.33
# Step 287: lat: 65.53, lon: -78.98, alt: 8.33
# Step 288: lat: 65.62, lon: -79.02, alt: 8.33
# Step 289: lat: 65.71, lon: -79.05, alt: 8.33
# Step 290: lat: 65.79, lon: -79.08, alt: 8.33
# Step 291: lat: 65.87, lon: -79.12, alt: 8.33
# Step 292: lat: 65.95, lon: -79.15, alt: 8.33
# Step 293: lat: 66.03, lon: -79.18, alt: 8.33
# Step 294: lat: 66.10, lon: -79.22, alt: 8.33
# Step 295: lat: 66.17, lon: -79.25, alt: 8.33
# Step 296: lat: 66.24, lon: -79.28, alt: 8.33
# Step 297: lat: 66.31, lon: -79.31, alt: 8.33
# Step 298: lat: 66.37, lon: -79.35, alt: 8.33
# Step 299: lat: 66.44, lon: -79.38, alt: 8.33
# Step 300: lat: 66.50, lon: -79.41, alt: 8.32
# Step 301: lat: 66.56, lon: -79.45, alt: 8.32
# Step 302: lat: 66.62, lon: -79.48, alt: 8.32
# Step 303: lat: 66.67, lon: -79.52, alt: 8.32
# Step 304: lat: 66.73, lon: -79.55, alt: 8.33
# Step 305: lat: 66.78, lon: -79.58, alt: 8.33
# Step 306: lat: 66.83, lon: -79.62, alt: 8.32
# Step 307: lat: 66.88, lon: -79.65, alt: 8.32
# Step 308: lat: 66.93, lon: -79.68, alt: 8.31
# Step 309: lat: 66.98, lon: -79.72, alt: 8.31
# Step 310: lat: 67.03, lon: -79.75, alt: 8.30
# Step 311: lat: 67.07, lon: -79.79, alt: 8.31
# Step 312: lat: 67.12, lon: -79.82, alt: 8.31
# Step 313: lat: 67.16, lon: -79.85, alt: 8.30
# Step 314: lat: 67.20, lon: -79.89, alt: 8.30
# Step 315: lat: 67.25, lon: -79.92, alt: 8.30
# Step 316: lat: 67.29, lon: -79.95, alt: 8.30
# Step 317: lat: 67.33, lon: -79.99, alt: 8.30
# Step 318: lat: 67.37, lon: -80.02, alt: 8.29
# Step 319: lat: 67.41, lon: -80.05, alt: 8.29
# Step 320: lat: 67.45, lon: -80.09, alt: 8.28
# Step 321: lat: 67.48, lon: -80.12, alt: 8.28
# Step 322: lat: 67.52, lon: -80.15, alt: 8.28
# Step 323: lat: 67.56, lon: -80.18, alt: 8.28
# Step 324: lat: 67.60, lon: -80.22, alt: 8.28
# Step 325: lat: 67.63, lon: -80.25, alt: 8.29
# Step 326: lat: 67.67, lon: -80.28, alt: 8.29
# Step 327: lat: 67.70, lon: -80.31, alt: 8.29
# Step 328: lat: 67.74, lon: -80.34, alt: 8.29
# Step 329: lat: 67.77, lon: -80.37, alt: 8.29
# Step 330: lat: 67.80, lon: -80.41, alt: 8.28
# Step 331: lat: 67.84, lon: -80.44, alt: 8.28
# Step 332: lat: 67.87, lon: -80.47, alt: 8.28
# Step 333: lat: 67.90, lon: -80.50, alt: 8.29
# Step 334: lat: 67.94, lon: -80.53, alt: 8.29
# Step 335: lat: 67.97, lon: -80.56, alt: 8.29
# Step 336: lat: 68.00, lon: -80.59, alt: 8.29
# Step 337: lat: 68.03, lon: -80.62, alt: 8.29
# Step 338: lat: 68.06, lon: -80.64, alt: 8.29
# Step 339: lat: 68.10, lon: -80.67, alt: 8.28
# Step 340: lat: 68.13, lon: -80.70, alt: 8.28
# Step 341: lat: 68.16, lon: -80.73, alt: 8.27
# Step 342: lat: 68.19, lon: -80.76, alt: 8.26
# Step 343: lat: 68.22, lon: -80.79, alt: 8.25
# Step 344: lat: 68.25, lon: -80.81, alt: 8.24
# Step 345: lat: 68.29, lon: -80.84, alt: 8.24
# Step 346: lat: 68.32, lon: -80.87, alt: 8.24
# Step 347: lat: 68.35, lon: -80.89, alt: 8.23
# Step 348: lat: 68.38, lon: -80.92, alt: 8.23
# Step 349: lat: 68.42, lon: -80.95, alt: 8.23
# Step 350: lat: 68.45, lon: -80.97, alt: 8.22
# Step 351: lat: 68.48, lon: -81.00, alt: 8.21
# Step 352: lat: 68.51, lon: -81.02, alt: 8.21
# Step 353: lat: 68.55, lon: -81.05, alt: 8.20
# Step 354: lat: 68.58, lon: -81.07, alt: 8.20
# Step 355: lat: 68.62, lon: -81.10, alt: 8.20
# Step 356: lat: 68.65, lon: -81.12, alt: 8.19
# Step 357: lat: 68.68, lon: -81.14, alt: 8.19
# Step 358: lat: 68.72, lon: -81.17, alt: 8.19
# Step 359: lat: 68.75, lon: -81.19, alt: 8.18
# Step 360: lat: 68.79, lon: -81.21, alt: 8.18
# Step 361: lat: 68.83, lon: -81.24, alt: 8.18
# Step 362: lat: 68.86, lon: -81.26, alt: 8.18
# Step 363: lat: 68.90, lon: -81.28, alt: 8.18
# Step 364: lat: 68.94, lon: -81.31, alt: 8.18
# Step 365: lat: 68.97, lon: -81.33, alt: 8.17
# Step 366: lat: 69.01, lon: -81.35, alt: 8.17
# Step 367: lat: 69.05, lon: -81.37, alt: 8.18
# Step 368: lat: 69.09, lon: -81.39, alt: 8.18
# Step 369: lat: 69.13, lon: -81.41, alt: 8.17
# Step 370: lat: 69.17, lon: -81.44, alt: 8.17
# Step 371: lat: 69.21, lon: -81.46, alt: 8.17
# Step 372: lat: 69.25, lon: -81.48, alt: 8.17
# Step 373: lat: 69.29, lon: -81.50, alt: 8.18
# Step 374: lat: 69.34, lon: -81.52, alt: 8.18
# Step 375: lat: 69.38, lon: -81.54, alt: 8.19
# Step 376: lat: 69.42, lon: -81.56, alt: 8.19
# Step 377: lat: 69.47, lon: -81.58, alt: 8.20
# Step 378: lat: 69.51, lon: -81.60, alt: 8.21
# Step 379: lat: 69.56, lon: -81.62, alt: 8.21
# Step 380: lat: 69.60, lon: -81.64, alt: 8.21
# Step 381: lat: 69.65, lon: -81.66, alt: 8.21
# Step 382: lat: 69.69, lon: -81.68, alt: 8.21
# Step 383: lat: 69.74, lon: -81.70, alt: 8.20
# Step 384: lat: 69.79, lon: -81.72, alt: 8.19
# Step 385: lat: 69.84, lon: -81.74, alt: 8.17
# Step 386: lat: 69.89, lon: -81.76, alt: 8.16
# Step 387: lat: 69.94, lon: -81.77, alt: 8.16
# Step 388: lat: 69.99, lon: -81.79, alt: 8.15
# Step 389: lat: 70.04, lon: -81.81, alt: 8.15
# Step 390: lat: 70.09, lon: -81.83, alt: 8.14
# Step 391: lat: 70.15, lon: -81.85, alt: 8.14
# Step 392: lat: 70.20, lon: -81.87, alt: 8.14
# Step 393: lat: 70.26, lon: -81.88, alt: 8.14
# Step 394: lat: 70.31, lon: -81.90, alt: 8.14
# Step 395: lat: 70.37, lon: -81.92, alt: 8.14
# Step 396: lat: 70.43, lon: -81.94, alt: 8.14
# Step 397: lat: 70.49, lon: -81.96, alt: 8.13
# Step 398: lat: 70.55, lon: -81.97, alt: 8.14
# Step 399: lat: 70.61, lon: -81.99, alt: 8.15
# Step 400: lat: 70.68, lon: -82.01, alt: 8.16
# Step 401: lat: 70.74, lon: -82.03, alt: 8.17
# Step 402: lat: 70.81, lon: -82.04, alt: 8.19
# Step 403: lat: 70.88, lon: -82.06, alt: 8.21
# Step 404: lat: 70.95, lon: -82.08, alt: 8.23
# Step 405: lat: 71.02, lon: -82.10, alt: 8.24
# Step 406: lat: 71.10, lon: -82.11, alt: 8.26
# Step 407: lat: 71.17, lon: -82.13, alt: 8.27
# Step 408: lat: 71.25, lon: -82.15, alt: 8.29
# Step 409: lat: 71.33, lon: -82.17, alt: 8.30
# Step 410: lat: 71.42, lon: -82.18, alt: 8.31
# Step 411: lat: 71.50, lon: -82.20, alt: 8.32
# Step 412: lat: 71.59, lon: -82.22, alt: 8.33
# Step 413: lat: 71.69, lon: -82.23, alt: 8.34
# Step 414: lat: 71.78, lon: -82.25, alt: 8.34
# Step 415: lat: 71.88, lon: -82.27, alt: 8.33
# Step 416: lat: 71.99, lon: -82.28, alt: 8.33
# Step 417: lat: 72.09, lon: -82.30, alt: 8.33
# Step 418: lat: 72.20, lon: -82.31, alt: 8.33
# Step 419: lat: 72.32, lon: -82.33, alt: 8.33
# Step 420: lat: 72.44, lon: -82.34, alt: 8.33
# Step 421: lat: 72.56, lon: -82.36, alt: 8.33
# Step 422: lat: 72.68, lon: -82.37, alt: 8.34
# Step 423: lat: 72.81, lon: -82.39, alt: 8.34
# Step 424: lat: 72.94, lon: -82.40, alt: 8.33
# Step 425: lat: 73.07, lon: -82.41, alt: 8.33
# Step 426: lat: 73.20, lon: -82.42, alt: 8.33
# Step 427: lat: 73.33, lon: -82.43, alt: 8.33
# Step 428: lat: 73.46, lon: -82.44, alt: 8.33
# Step 429: lat: 73.59, lon: -82.45, alt: 8.32
# Step 430: lat: 73.73, lon: -82.46, alt: 8.32
# Step 431: lat: 73.86, lon: -82.47, alt: 8.32
# Step 432: lat: 73.99, lon: -82.48, alt: 8.31
# Step 433: lat: 74.12, lon: -82.48, alt: 8.31
# Step 434: lat: 74.24, lon: -82.49, alt: 8.33
# Step 435: lat: 74.37, lon: -82.50, alt: 8.34
# Step 436: lat: 74.49, lon: -82.50, alt: 8.34
# Step 437: lat: 74.61, lon: -82.50, alt: 8.34
# Step 438: lat: 74.72, lon: -82.51, alt: 8.33
# Step 439: lat: 74.84, lon: -82.51, alt: 8.32
# Step 440: lat: 74.94, lon: -82.52, alt: 8.31
# Step 441: lat: 75.05, lon: -82.52, alt: 8.31
# Step 442: lat: 75.15, lon: -82.52, alt: 8.31
# Step 443: lat: 75.25, lon: -82.52, alt: 8.32
# Step 444: lat: 75.35, lon: -82.52, alt: 8.33
# Step 445: lat: 75.45, lon: -82.52, alt: 8.33
# Step 446: lat: 75.54, lon: -82.52, alt: 8.33
# Step 447: lat: 75.62, lon: -82.52, alt: 8.32
# Step 448: lat: 75.71, lon: -82.52, alt: 8.33
# Step 449: lat: 75.79, lon: -82.52, alt: 8.33
# Step 450: lat: 75.86, lon: -82.52, alt: 8.33
# Step 451: lat: 75.93, lon: -82.52, alt: 8.33
# Step 452: lat: 76.00, lon: -82.51, alt: 8.33
# Step 453: lat: 76.06, lon: -82.51, alt: 8.32
# Step 454: lat: 76.13, lon: -82.51, alt: 8.32
# Step 455: lat: 76.18, lon: -82.50, alt: 8.32
# Step 456: lat: 76.24, lon: -82.50, alt: 8.32
# Step 457: lat: 76.29, lon: -82.50, alt: 8.32
# Step 458: lat: 76.34, lon: -82.49, alt: 8.32
# Step 459: lat: 76.39, lon: -82.49, alt: 8.33
# Step 460: lat: 76.44, lon: -82.48, alt: 8.33
# Step 461: lat: 76.48, lon: -82.48, alt: 8.33
# Step 462: lat: 76.52, lon: -82.47, alt: 8.32
# Step 463: lat: 76.56, lon: -82.47, alt: 8.32
# Step 464: lat: 76.60, lon: -82.46, alt: 8.31
# Step 465: lat: 76.64, lon: -82.46, alt: 8.31
# Step 466: lat: 76.67, lon: -82.45, alt: 8.31
# Step 467: lat: 76.71, lon: -82.45, alt: 8.31
# Step 468: lat: 76.74, lon: -82.44, alt: 8.31
# Step 469: lat: 76.77, lon: -82.44, alt: 8.31
# Step 470: lat: 76.80, lon: -82.43, alt: 8.31
# Step 471: lat: 76.83, lon: -82.43, alt: 8.31
# Step 472: lat: 76.85, lon: -82.42, alt: 8.31
# Step 473: lat: 76.88, lon: -82.41, alt: 8.31
# Step 474: lat: 76.90, lon: -82.41, alt: 8.31
# Step 475: lat: 76.93, lon: -82.40, alt: 8.31
# Step 476: lat: 76.95, lon: -82.40, alt: 8.31
# Step 477: lat: 76.97, lon: -82.39, alt: 8.31
# Step 478: lat: 76.99, lon: -82.38, alt: 8.31
# Step 479: lat: 77.01, lon: -82.38, alt: 8.30
# Step 480: lat: 77.02, lon: -82.37, alt: 8.30
# Step 481: lat: 77.04, lon: -82.36, alt: 8.30
# Step 482: lat: 77.06, lon: -82.36, alt: 8.30
# Step 483: lat: 77.07, lon: -82.35, alt: 8.30
# Step 484: lat: 77.09, lon: -82.34, alt: 8.31
# Step 485: lat: 77.10, lon: -82.34, alt: 8.31
# Step 486: lat: 77.11, lon: -82.33, alt: 8.30
# Step 487: lat: 77.12, lon: -82.32, alt: 8.30
# Step 488: lat: 77.13, lon: -82.31, alt: 8.31
# Step 489: lat: 77.15, lon: -82.31, alt: 8.32
# Step 490: lat: 77.16, lon: -82.30, alt: 8.32
# Step 491: lat: 77.16, lon: -82.29, alt: 8.32
# Step 492: lat: 77.17, lon: -82.29, alt: 8.32
# Step 493: lat: 77.18, lon: -82.28, alt: 8.32
# Step 494: lat: 77.19, lon: -82.27, alt: 8.33
# Step 495: lat: 77.20, lon: -82.26, alt: 8.33
# Step 496: lat: 77.20, lon: -82.26, alt: 8.33
# Step 497: lat: 77.21, lon: -82.25, alt: 8.33
# Step 498: lat: 77.22, lon: -82.24, alt: 8.34
# Step 499: lat: 77.22, lon: -82.24, alt: 8.34
# Step 500: lat: 77.23, lon: -82.23, alt: 8.35
# Step 501: lat: 77.23, lon: -82.22, alt: 8.35
# Step 502: lat: 77.24, lon: -82.21, alt: 8.34
# Step 503: lat: 77.24, lon: -82.21, alt: 8.34
# Step 504: lat: 77.25, lon: -82.20, alt: 8.33
# Step 505: lat: 77.25, lon: -82.19, alt: 8.33
# Step 506: lat: 77.25, lon: -82.18, alt: 8.32
# Step 507: lat: 77.26, lon: -82.18, alt: 8.32
# Step 508: lat: 77.26, lon: -82.17, alt: 8.32
# Step 509: lat: 77.26, lon: -82.16, alt: 8.32
# Step 510: lat: 77.27, lon: -82.15, alt: 8.33
# Step 511: lat: 77.27, lon: -82.15, alt: 8.34
# Step 512: lat: 77.27, lon: -82.14, alt: 8.35
# Step 513: lat: 77.27, lon: -82.13, alt: 8.36
# Step 514: lat: 77.28, lon: -82.12, alt: 8.37
# Step 515: lat: 77.28, lon: -82.12, alt: 8.38
# Step 516: lat: 77.28, lon: -82.11, alt: 8.40
# Step 517: lat: 77.28, lon: -82.10, alt: 8.42
# Step 518: lat: 77.28, lon: -82.09, alt: 8.44
# Step 519: lat: 77.28, lon: -82.09, alt: 8.46
# Step 520: lat: 77.28, lon: -82.08, alt: 8.49
# Step 521: lat: 77.28, lon: -82.07, alt: 8.51
# Step 522: lat: 77.27, lon: -82.06, alt: 8.53
# Step 523: lat: 77.27, lon: -82.06, alt: 8.55
# Step 524: lat: 77.27, lon: -82.05, alt: 8.56
# Step 525: lat: 77.27, lon: -82.04, alt: 8.57
# Step 526: lat: 77.26, lon: -82.03, alt: 8.57
# Step 527: lat: 77.26, lon: -82.03, alt: 8.58
# Step 528: lat: 77.26, lon: -82.02, alt: 8.59
# Step 529: lat: 77.26, lon: -82.01, alt: 8.60
# Step 530: lat: 77.25, lon: -82.00, alt: 8.60
# Step 531: lat: 77.25, lon: -81.99, alt: 8.61
# Step 532: lat: 77.25, lon: -81.99, alt: 8.62
# Step 533: lat: 77.25, lon: -81.98, alt: 8.62
# Step 534: lat: 77.24, lon: -81.97, alt: 8.62
# Step 535: lat: 77.24, lon: -81.96, alt: 8.63
# Step 536: lat: 77.24, lon: -81.96, alt: 8.63
# Step 537: lat: 77.23, lon: -81.95, alt: 8.63
# Step 538: lat: 77.23, lon: -81.94, alt: 8.62
# Step 539: lat: 77.23, lon: -81.93, alt: 8.61
# Step 540: lat: 77.23, lon: -81.93, alt: 8.60
# Step 541: lat: 77.23, lon: -81.92, alt: 8.58
# Step 542: lat: 77.23, lon: -81.91, alt: 8.55
# Step 543: lat: 77.22, lon: -81.91, alt: 8.53
# Step 544: lat: 77.22, lon: -81.90, alt: 8.50
# Step 545: lat: 77.22, lon: -81.89, alt: 8.47
# Step 546: lat: 77.23, lon: -81.88, alt: 8.44
# Step 547: lat: 77.23, lon: -81.88, alt: 8.42
# Step 548: lat: 77.23, lon: -81.87, alt: 8.39
# Step 549: lat: 77.23, lon: -81.86, alt: 8.37
# Step 550: lat: 77.23, lon: -81.85, alt: 8.36
# Step 551: lat: 77.24, lon: -81.85, alt: 8.34
# Step 552: lat: 77.24, lon: -81.84, alt: 8.33
# Step 553: lat: 77.24, lon: -81.83, alt: 8.32
# Step 554: lat: 77.24, lon: -81.82, alt: 8.33
# Step 555: lat: 77.25, lon: -81.82, alt: 8.33
# Step 556: lat: 77.25, lon: -81.81, alt: 8.34
# Step 557: lat: 77.25, lon: -81.80, alt: 8.34
# Step 558: lat: 77.25, lon: -81.80, alt: 8.35
# Step 559: lat: 77.25, lon: -81.79, alt: 8.37
# Step 560: lat: 77.25, lon: -81.78, alt: 8.38
# Step 561: lat: 77.25, lon: -81.77, alt: 8.39
# Step 562: lat: 77.25, lon: -81.77, alt: 8.41
# Step 563: lat: 77.25, lon: -81.76, alt: 8.42
# Step 564: lat: 77.25, lon: -81.75, alt: 8.43
# Step 565: lat: 77.25, lon: -81.74, alt: 8.43
# Step 566: lat: 77.25, lon: -81.74, alt: 8.43
# Step 567: lat: 77.25, lon: -81.73, alt: 8.44
# Step 568: lat: 77.25, lon: -81.72, alt: 8.44
# Step 569: lat: 77.24, lon: -81.71, alt: 8.44
# Step 570: lat: 77.24, lon: -81.71, alt: 8.45
# Step 571: lat: 77.24, lon: -81.70, alt: 8.45
# Step 572: lat: 77.24, lon: -81.69, alt: 8.46
# Step 573: lat: 77.24, lon: -81.68, alt: 8.47
# Step 574: lat: 77.23, lon: -81.68, alt: 8.47
# Step 575: lat: 77.23, lon: -81.67, alt: 8.48
# Step 576: lat: 77.23, lon: -81.66, alt: 8.48
# Step 577: lat: 77.23, lon: -81.65, alt: 8.48
# Step 578: lat: 77.23, lon: -81.65, alt: 8.48
# Step 579: lat: 77.22, lon: -81.64, alt: 8.48
# Step 580: lat: 77.22, lon: -81.63, alt: 8.48
# Step 581: lat: 77.22, lon: -81.62, alt: 8.48
# Step 582: lat: 77.22, lon: -81.62, alt: 8.47
# Step 583: lat: 77.21, lon: -81.61, alt: 8.46
# Step 584: lat: 77.21, lon: -81.60, alt: 8.45
# Step 585: lat: 77.21, lon: -81.60, alt: 8.44
# Step 586: lat: 77.21, lon: -81.59, alt: 8.43
# Step 587: lat: 77.21, lon: -81.58, alt: 8.41
# Step 588: lat: 77.21, lon: -81.57, alt: 8.39
# Step 589: lat: 77.21, lon: -81.57, alt: 8.37
# Step 590: lat: 77.21, lon: -81.56, alt: 8.36
# Step 591: lat: 77.21, lon: -81.55, alt: 8.34
# Step 592: lat: 77.21, lon: -81.54, alt: 8.33
# Step 593: lat: 77.21, lon: -81.54, alt: 8.31
# Step 594: lat: 77.21, lon: -81.53, alt: 8.30
# Step 595: lat: 77.21, lon: -81.52, alt: 8.29
# Step 596: lat: 77.21, lon: -81.52, alt: 8.29
# Step 597: lat: 77.21, lon: -81.51, alt: 8.29
# Step 598: lat: 77.21, lon: -81.50, alt: 8.29
# Step 599: lat: 77.21, lon: -81.49, alt: 8.29
# Step 600: lat: 77.21, lon: -81.49, alt: 8.29
# Step 601: lat: 77.20, lon: -81.48, alt: 8.30
# Step 602: lat: 77.20, lon: -81.47, alt: 8.32
# Step 603: lat: 77.20, lon: -81.46, alt: 8.32
# Step 604: lat: 77.20, lon: -81.46, alt: 8.33
# Step 605: lat: 77.20, lon: -81.45, alt: 8.33
# Step 606: lat: 77.20, lon: -81.44, alt: 8.34
# Step 607: lat: 77.20, lon: -81.44, alt: 8.34
# Step 608: lat: 77.20, lon: -81.43, alt: 8.34
# Step 609: lat: 77.20, lon: -81.42, alt: 8.34
# Step 610: lat: 77.20, lon: -81.41, alt: 8.33
# Step 611: lat: 77.20, lon: -81.41, alt: 8.33
# Step 612: lat: 77.20, lon: -81.40, alt: 8.32
# Step 613: lat: 77.20, lon: -81.39, alt: 8.32
# Step 614: lat: 77.20, lon: -81.39, alt: 8.32
# Step 615: lat: 77.20, lon: -81.38, alt: 8.33
# Step 616: lat: 77.20, lon: -81.37, alt: 8.34
# Step 617: lat: 77.20, lon: -81.36, alt: 8.35
# Step 618: lat: 77.20, lon: -81.36, alt: 8.35
# Step 619: lat: 77.20, lon: -81.35, alt: 8.36
# Step 620: lat: 77.20, lon: -81.34, alt: 8.36
# Step 621: lat: 77.20, lon: -81.33, alt: 8.36
# Step 622: lat: 77.20, lon: -81.33, alt: 8.36
# Step 623: lat: 77.20, lon: -81.32, alt: 8.36
# Step 624: lat: 77.20, lon: -81.31, alt: 8.35
# Step 625: lat: 77.19, lon: -81.31, alt: 8.35
# Step 626: lat: 77.19, lon: -81.30, alt: 8.35
# Step 627: lat: 77.19, lon: -81.29, alt: 8.34
# Step 628: lat: 77.19, lon: -81.28, alt: 8.33
# Step 629: lat: 77.19, lon: -81.28, alt: 8.32
# Step 630: lat: 77.19, lon: -81.27, alt: 8.31
# Step 631: lat: 77.19, lon: -81.26, alt: 8.31
# Step 632: lat: 77.20, lon: -81.25, alt: 8.31
# Step 633: lat: 77.20, lon: -81.25, alt: 8.30
# Step 634: lat: 77.20, lon: -81.24, alt: 8.30
# Step 635: lat: 77.20, lon: -81.23, alt: 8.30
# Step 636: lat: 77.20, lon: -81.23, alt: 8.30
# Step 637: lat: 77.20, lon: -81.22, alt: 8.30
# Step 638: lat: 77.20, lon: -81.21, alt: 8.31
# Step 639: lat: 77.20, lon: -81.20, alt: 8.31
# Step 640: lat: 77.20, lon: -81.20, alt: 8.32
# Step 641: lat: 77.21, lon: -81.19, alt: 8.33
# Step 642: lat: 77.21, lon: -81.18, alt: 8.34
# Step 643: lat: 77.21, lon: -81.18, alt: 8.34
# Step 644: lat: 77.21, lon: -81.17, alt: 8.34
# Step 645: lat: 77.21, lon: -81.16, alt: 8.34
# Step 646: lat: 77.22, lon: -81.15, alt: 8.34
# Step 647: lat: 77.22, lon: -81.15, alt: 8.34
# Step 648: lat: 77.22, lon: -81.14, alt: 8.33
# Step 649: lat: 77.22, lon: -81.13, alt: 8.32
# Step 650: lat: 77.22, lon: -81.12, alt: 8.32
# Step 651: lat: 77.23, lon: -81.12, alt: 8.31
# Step 652: lat: 77.23, lon: -81.11, alt: 8.31
# Step 653: lat: 77.23, lon: -81.10, alt: 8.31
# Step 654: lat: 77.23, lon: -81.10, alt: 8.32
# Step 655: lat: 77.24, lon: -81.09, alt: 8.31
# Step 656: lat: 77.24, lon: -81.08, alt: 8.31
# Step 657: lat: 77.24, lon: -81.07, alt: 8.31
# Step 658: lat: 77.25, lon: -81.07, alt: 8.30
# Step 659: lat: 77.25, lon: -81.06, alt: 8.30
# Step 660: lat: 77.25, lon: -81.05, alt: 8.30
# Step 661: lat: 77.25, lon: -81.05, alt: 8.31
# Step 662: lat: 77.26, lon: -81.04, alt: 8.31
# Step 663: lat: 77.26, lon: -81.03, alt: 8.31
# Step 664: lat: 77.26, lon: -81.02, alt: 8.32
# Step 665: lat: 77.26, lon: -81.02, alt: 8.32
# Step 666: lat: 77.26, lon: -81.01, alt: 8.32
# Step 667: lat: 77.26, lon: -81.00, alt: 8.33
# Step 668: lat: 77.26, lon: -80.99, alt: 8.33
# Step 669: lat: 77.26, lon: -80.99, alt: 8.33
# Step 670: lat: 77.26, lon: -80.98, alt: 8.33
# Step 671: lat: 77.26, lon: -80.97, alt: 8.33
# Step 672: lat: 77.26, lon: -80.97, alt: 8.33
# Step 673: lat: 77.26, lon: -80.96, alt: 8.33
# Step 674: lat: 77.26, lon: -80.95, alt: 8.32
# Step 675: lat: 77.26, lon: -80.94, alt: 8.32
# Step 676: lat: 77.26, lon: -80.94, alt: 8.32
# Step 677: lat: 77.26, lon: -80.93, alt: 8.33
# Step 678: lat: 77.26, lon: -80.92, alt: 8.33
# Step 679: lat: 77.26, lon: -80.92, alt: 8.33
# Step 680: lat: 77.25, lon: -80.91, alt: 8.33
# Step 681: lat: 77.25, lon: -80.90, alt: 8.32
# Step 682: lat: 77.25, lon: -80.89, alt: 8.32
# Step 683: lat: 77.25, lon: -80.89, alt: 8.32
# Step 684: lat: 77.25, lon: -80.88, alt: 8.31
# Step 685: lat: 77.24, lon: -80.87, alt: 8.30
# Step 686: lat: 77.24, lon: -80.87, alt: 8.30
# Step 687: lat: 77.24, lon: -80.86, alt: 8.29
# Step 688: lat: 77.23, lon: -80.85, alt: 8.30
# Step 689: lat: 77.23, lon: -80.85, alt: 8.30
# Step 690: lat: 77.23, lon: -80.84, alt: 8.30
# Step 691: lat: 77.23, lon: -80.83, alt: 8.30
# Step 692: lat: 77.22, lon: -80.83, alt: 8.30
# Step 693: lat: 77.22, lon: -80.82, alt: 8.29
# Step 694: lat: 77.22, lon: -80.81, alt: 8.29
# Step 695: lat: 77.21, lon: -80.81, alt: 8.29
# Step 696: lat: 77.21, lon: -80.80, alt: 8.29
# Step 697: lat: 77.21, lon: -80.79, alt: 8.28
# Step 698: lat: 77.20, lon: -80.78, alt: 8.28
# Step 699: lat: 77.20, lon: -80.78, alt: 8.27
# Step 700: lat: 77.19, lon: -80.77, alt: 8.28
# Step 701: lat: 77.19, lon: -80.76, alt: 8.28
# Step 702: lat: 77.18, lon: -80.76, alt: 8.28
# Step 703: lat: 77.18, lon: -80.75, alt: 8.28
# Step 704: lat: 77.18, lon: -80.74, alt: 8.28
# Step 705: lat: 77.17, lon: -80.74, alt: 8.28
# Step 706: lat: 77.17, lon: -80.73, alt: 8.28
# Step 707: lat: 77.16, lon: -80.72, alt: 8.28
# Step 708: lat: 77.16, lon: -80.72, alt: 8.28
# Step 709: lat: 77.15, lon: -80.71, alt: 8.28
# Step 710: lat: 77.15, lon: -80.70, alt: 8.28
# Step 711: lat: 77.14, lon: -80.70, alt: 8.28
# Step 712: lat: 77.14, lon: -80.69, alt: 8.27
# Step 713: lat: 77.13, lon: -80.68, alt: 8.27
# Step 714: lat: 77.13, lon: -80.68, alt: 8.27
# Step 715: lat: 77.13, lon: -80.67, alt: 8.27
# Step 716: lat: 77.12, lon: -80.66, alt: 8.27
# Step 717: lat: 77.12, lon: -80.66, alt: 8.28
# Step 718: lat: 77.11, lon: -80.65, alt: 8.29
# Step 719: lat: 77.11, lon: -80.65, alt: 8.29
#
# Episode terminated: Time limit reached
# Collected 720 state-action pairs from expert.
# Initial position: [np.float64(42.6), np.float64(-76.5)], Target position: [77.3, -80.5], End position: [np.float64(77.1), np.float64(-80.6)], Distance: 11.703635446228343 km
# num_samples: 10, acc_bounds: (-0.1, 0.1), noise_std: 0.1, num_iterations: 1, horizon: 10
# Step 0: lat: 42.78, lon: -76.49, alt: 9.88
# Step 1: lat: 42.95, lon: -76.48, alt: 9.76
# Step 2: lat: 43.13, lon: -76.47, alt: 9.64
# Step 3: lat: 43.31, lon: -76.46, alt: 9.52
# Step 4: lat: 43.49, lon: -76.44, alt: 9.40
# Step 5: lat: 43.67, lon: -76.43, alt: 9.28
# Step 6: lat: 43.86, lon: -76.42, alt: 9.16
# Step 7: lat: 44.04, lon: -76.40, alt: 9.04
# Step 8: lat: 44.23, lon: -76.39, alt: 8.93
# Step 9: lat: 44.42, lon: -76.37, alt: 8.82
# Step 10: lat: 44.60, lon: -76.36, alt: 8.72
# Step 11: lat: 44.79, lon: -76.34, alt: 8.63
# Step 12: lat: 44.97, lon: -76.32, alt: 8.55
# Step 13: lat: 45.14, lon: -76.30, alt: 8.47
# Step 14: lat: 45.31, lon: -76.29, alt: 8.40
# Step 15: lat: 45.47, lon: -76.27, alt: 8.34
# Step 16: lat: 45.62, lon: -76.26, alt: 8.29
# Step 17: lat: 45.75, lon: -76.25, alt: 8.25
# Step 18: lat: 45.88, lon: -76.24, alt: 8.22
# Step 19: lat: 45.99, lon: -76.23, alt: 8.21
# Step 20: lat: 46.10, lon: -76.22, alt: 8.20
# Step 21: lat: 46.20, lon: -76.21, alt: 8.20
# Step 22: lat: 46.29, lon: -76.21, alt: 8.22
# Step 23: lat: 46.37, lon: -76.20, alt: 8.25
# Step 24: lat: 46.45, lon: -76.20, alt: 8.28
# Step 25: lat: 46.52, lon: -76.19, alt: 8.33
# Step 26: lat: 46.59, lon: -76.19, alt: 8.40
# Step 27: lat: 46.65, lon: -76.18, alt: 8.47
# Step 28: lat: 46.72, lon: -76.18, alt: 8.55
# Step 29: lat: 46.78, lon: -76.18, alt: 8.65
# Step 30: lat: 46.84, lon: -76.17, alt: 8.76
# Step 31: lat: 46.90, lon: -76.17, alt: 8.87
# Step 32: lat: 46.96, lon: -76.17, alt: 8.99
# Step 33: lat: 47.02, lon: -76.17, alt: 9.11
# Step 34: lat: 47.09, lon: -76.17, alt: 9.23
# Step 35: lat: 47.15, lon: -76.16, alt: 9.35
# Step 36: lat: 47.22, lon: -76.16, alt: 9.47
# Step 37: lat: 47.29, lon: -76.16, alt: 9.59
# Step 38: lat: 47.36, lon: -76.16, alt: 9.71
# Step 39: lat: 47.43, lon: -76.16, alt: 9.83
# Step 40: lat: 47.50, lon: -76.16, alt: 9.95
# Step 41: lat: 47.58, lon: -76.16, alt: 10.07
# Step 42: lat: 47.65, lon: -76.16, alt: 10.19
# Step 43: lat: 47.73, lon: -76.16, alt: 10.31
# Step 44: lat: 47.81, lon: -76.15, alt: 10.43
# Step 45: lat: 47.89, lon: -76.15, alt: 10.55
# Step 46: lat: 47.97, lon: -76.15, alt: 10.67
# Step 47: lat: 48.05, lon: -76.15, alt: 10.79
# Step 48: lat: 48.12, lon: -76.16, alt: 10.91
# Step 49: lat: 48.20, lon: -76.16, alt: 11.02
# Step 50: lat: 48.27, lon: -76.16, alt: 11.14
# Step 51: lat: 48.34, lon: -76.16, alt: 11.26
# Step 52: lat: 48.41, lon: -76.16, alt: 11.38
# Step 53: lat: 48.48, lon: -76.16, alt: 11.50
# Step 54: lat: 48.55, lon: -76.16, alt: 11.62
# Step 55: lat: 48.62, lon: -76.16, alt: 11.74
# Step 56: lat: 48.69, lon: -76.16, alt: 11.86
# Step 57: lat: 48.76, lon: -76.16, alt: 11.98
# Step 58: lat: 48.83, lon: -76.17, alt: 12.10
# Step 59: lat: 48.89, lon: -76.17, alt: 12.22
# Step 60: lat: 48.96, lon: -76.17, alt: 12.34
# Step 61: lat: 49.03, lon: -76.17, alt: 12.46
# Step 62: lat: 49.10, lon: -76.17, alt: 12.58
# Step 63: lat: 49.16, lon: -76.17, alt: 12.70
# Step 64: lat: 49.23, lon: -76.18, alt: 12.82
# Step 65: lat: 49.30, lon: -76.18, alt: 12.94
# Step 66: lat: 49.36, lon: -76.18, alt: 13.06
# Step 67: lat: 49.43, lon: -76.18, alt: 13.18
# Step 68: lat: 49.50, lon: -76.18, alt: 13.30
# Step 69: lat: 49.57, lon: -76.19, alt: 13.42
# Step 70: lat: 49.64, lon: -76.19, alt: 13.54
# Step 71: lat: 49.71, lon: -76.19, alt: 13.66
# Step 72: lat: 49.78, lon: -76.19, alt: 13.78
# Step 73: lat: 49.85, lon: -76.20, alt: 13.90
# Step 74: lat: 49.92, lon: -76.20, alt: 14.02
# Step 75: lat: 49.99, lon: -76.20, alt: 14.14
# Step 76: lat: 50.06, lon: -76.20, alt: 14.26
# Step 77: lat: 50.13, lon: -76.20, alt: 14.38
# Step 78: lat: 50.21, lon: -76.20, alt: 14.50
# Step 79: lat: 50.28, lon: -76.20, alt: 14.62
# Step 80: lat: 50.35, lon: -76.20, alt: 14.74
# Step 81: lat: 50.43, lon: -76.21, alt: 14.86
# Step 82: lat: 50.50, lon: -76.21, alt: 14.98
# Step 83: lat: 50.58, lon: -76.21, alt: 15.10
# Step 84: lat: 50.65, lon: -76.21, alt: 15.22
# Step 85: lat: 50.72, lon: -76.21, alt: 15.34
# Step 86: lat: 50.80, lon: -76.20, alt: 15.46
# Step 87: lat: 50.87, lon: -76.20, alt: 15.58
# Step 88: lat: 50.94, lon: -76.20, alt: 15.70
# Step 89: lat: 51.01, lon: -76.20, alt: 15.82
# Step 90: lat: 51.08, lon: -76.20, alt: 15.94
# Step 91: lat: 51.15, lon: -76.20, alt: 16.06
# Step 92: lat: 51.22, lon: -76.20, alt: 16.18
# Step 93: lat: 51.29, lon: -76.19, alt: 16.30
# Step 94: lat: 51.35, lon: -76.19, alt: 16.42
# Step 95: lat: 51.42, lon: -76.19, alt: 16.54
# Step 96: lat: 51.48, lon: -76.19, alt: 16.65
# Step 97: lat: 51.55, lon: -76.19, alt: 16.77
# Step 98: lat: 51.61, lon: -76.18, alt: 16.89
# Step 99: lat: 51.68, lon: -76.18, alt: 17.01
# Step 100: lat: 51.74, lon: -76.18, alt: 17.13
# Step 101: lat: 51.80, lon: -76.18, alt: 17.24
# Step 102: lat: 51.86, lon: -76.18, alt: 17.35
# Step 103: lat: 51.92, lon: -76.17, alt: 17.44
# Step 104: lat: 51.98, lon: -76.17, alt: 17.52
# Step 105: lat: 52.04, lon: -76.17, alt: 17.59
# Step 106: lat: 52.10, lon: -76.17, alt: 17.65
# Step 107: lat: 52.16, lon: -76.17, alt: 17.70
# Step 108: lat: 52.21, lon: -76.16, alt: 17.75
# Step 109: lat: 52.27, lon: -76.16, alt: 17.79
# Step 110: lat: 52.33, lon: -76.16, alt: 17.83
# Step 111: lat: 52.38, lon: -76.16, alt: 17.85
# Step 112: lat: 52.44, lon: -76.16, alt: 17.86
# Step 113: lat: 52.49, lon: -76.15, alt: 17.87
# Step 114: lat: 52.54, lon: -76.15, alt: 17.88
# Step 115: lat: 52.60, lon: -76.15, alt: 17.87
# Step 116: lat: 52.65, lon: -76.15, alt: 17.87
# Step 117: lat: 52.70, lon: -76.14, alt: 17.85
# Step 118: lat: 52.75, lon: -76.14, alt: 17.84
# Step 119: lat: 52.80, lon: -76.14, alt: 17.81
# Step 120: lat: 52.85, lon: -76.14, alt: 17.78
# Step 121: lat: 52.90, lon: -76.13, alt: 17.74
# Step 122: lat: 52.95, lon: -76.13, alt: 17.69
# Step 123: lat: 53.00, lon: -76.13, alt: 17.64
# Step 124: lat: 53.05, lon: -76.13, alt: 17.58
# Step 125: lat: 53.10, lon: -76.12, alt: 17.51
# Step 126: lat: 53.14, lon: -76.12, alt: 17.44
# Step 127: lat: 53.19, lon: -76.12, alt: 17.36
# Step 128: lat: 53.24, lon: -76.11, alt: 17.27
# Step 129: lat: 53.28, lon: -76.11, alt: 17.16
# Step 130: lat: 53.33, lon: -76.11, alt: 17.05
# Step 131: lat: 53.38, lon: -76.10, alt: 16.93
# Step 132: lat: 53.42, lon: -76.10, alt: 16.81
# Step 133: lat: 53.47, lon: -76.10, alt: 16.69
# Step 134: lat: 53.52, lon: -76.09, alt: 16.57
# Step 135: lat: 53.56, lon: -76.09, alt: 16.45
# Step 136: lat: 53.61, lon: -76.09, alt: 16.33
# Step 137: lat: 53.65, lon: -76.08, alt: 16.21
# Step 138: lat: 53.70, lon: -76.08, alt: 16.09
# Step 139: lat: 53.75, lon: -76.08, alt: 15.97
# Step 140: lat: 53.79, lon: -76.07, alt: 15.85
# Step 141: lat: 53.84, lon: -76.07, alt: 15.73
# Step 142: lat: 53.89, lon: -76.07, alt: 15.61
# Step 143: lat: 53.94, lon: -76.06, alt: 15.49
# Step 144: lat: 53.98, lon: -76.06, alt: 15.37
# Step 145: lat: 54.03, lon: -76.06, alt: 15.25
# Step 146: lat: 54.08, lon: -76.06, alt: 15.13
# Step 147: lat: 54.13, lon: -76.06, alt: 15.01
# Step 148: lat: 54.18, lon: -76.05, alt: 14.89
# Step 149: lat: 54.23, lon: -76.05, alt: 14.77
# Step 150: lat: 54.28, lon: -76.05, alt: 14.65
# Step 151: lat: 54.33, lon: -76.05, alt: 14.53
# Step 152: lat: 54.38, lon: -76.05, alt: 14.41
# Step 153: lat: 54.43, lon: -76.05, alt: 14.29
# Step 154: lat: 54.48, lon: -76.05, alt: 14.17
# Step 155: lat: 54.53, lon: -76.05, alt: 14.05
# Step 156: lat: 54.58, lon: -76.05, alt: 13.93
# Step 157: lat: 54.63, lon: -76.05, alt: 13.81
# Step 158: lat: 54.69, lon: -76.05, alt: 13.69
# Step 159: lat: 54.74, lon: -76.05, alt: 13.57
# Step 160: lat: 54.79, lon: -76.05, alt: 13.45
# Step 161: lat: 54.85, lon: -76.06, alt: 13.33
# Step 162: lat: 54.90, lon: -76.06, alt: 13.21
# Step 163: lat: 54.96, lon: -76.06, alt: 13.09
# Step 164: lat: 55.02, lon: -76.07, alt: 12.97
# Step 165: lat: 55.07, lon: -76.07, alt: 12.85
# Step 166: lat: 55.13, lon: -76.08, alt: 12.73
# Step 167: lat: 55.19, lon: -76.08, alt: 12.61
# Step 168: lat: 55.25, lon: -76.09, alt: 12.49
# Step 169: lat: 55.31, lon: -76.09, alt: 12.37
# Step 170: lat: 55.37, lon: -76.10, alt: 12.25
# Step 171: lat: 55.43, lon: -76.11, alt: 12.13
# Step 172: lat: 55.49, lon: -76.12, alt: 12.01
# Step 173: lat: 55.56, lon: -76.12, alt: 11.89
# Step 174: lat: 55.62, lon: -76.13, alt: 11.77
# Step 175: lat: 55.69, lon: -76.14, alt: 11.65
# Step 176: lat: 55.75, lon: -76.15, alt: 11.53
# Step 177: lat: 55.82, lon: -76.16, alt: 11.41
# Step 178: lat: 55.88, lon: -76.17, alt: 11.29
# Step 179: lat: 55.95, lon: -76.18, alt: 11.17
# Step 180: lat: 56.02, lon: -76.20, alt: 11.05
# Step 181: lat: 56.09, lon: -76.21, alt: 10.93
# Step 182: lat: 56.16, lon: -76.22, alt: 10.81
# Step 183: lat: 56.24, lon: -76.23, alt: 10.69
# Step 184: lat: 56.31, lon: -76.25, alt: 10.57
# Step 185: lat: 56.38, lon: -76.26, alt: 10.45
# Step 186: lat: 56.46, lon: -76.28, alt: 10.33
# Step 187: lat: 56.54, lon: -76.29, alt: 10.21
# Step 188: lat: 56.61, lon: -76.31, alt: 10.09
# Step 189: lat: 56.69, lon: -76.32, alt: 9.97
# Step 190: lat: 56.76, lon: -76.34, alt: 9.85
# Step 191: lat: 56.84, lon: -76.36, alt: 9.73
# Step 192: lat: 56.91, lon: -76.37, alt: 9.61
# Step 193: lat: 56.99, lon: -76.39, alt: 9.49
# Step 194: lat: 57.07, lon: -76.41, alt: 9.37
# Step 195: lat: 57.14, lon: -76.43, alt: 9.25
# Step 196: lat: 57.22, lon: -76.45, alt: 9.13
# Step 197: lat: 57.30, lon: -76.46, alt: 9.01
# Step 198: lat: 57.38, lon: -76.48, alt: 8.90
# Step 199: lat: 57.46, lon: -76.50, alt: 8.79
# Step 200: lat: 57.54, lon: -76.52, alt: 8.69
# Step 201: lat: 57.62, lon: -76.54, alt: 8.61
# Step 202: lat: 57.70, lon: -76.56, alt: 8.53
# Step 203: lat: 57.78, lon: -76.59, alt: 8.45
# Step 204: lat: 57.87, lon: -76.61, alt: 8.39
# Step 205: lat: 57.95, lon: -76.63, alt: 8.32
# Step 206: lat: 58.04, lon: -76.65, alt: 8.26
# Step 207: lat: 58.13, lon: -76.67, alt: 8.20
# Step 208: lat: 58.21, lon: -76.69, alt: 8.15
# Step 209: lat: 58.30, lon: -76.72, alt: 8.11
# Step 210: lat: 58.39, lon: -76.74, alt: 8.08
# Step 211: lat: 58.48, lon: -76.76, alt: 8.07
# Step 212: lat: 58.57, lon: -76.78, alt: 8.05
# Step 213: lat: 58.66, lon: -76.81, alt: 8.04
# Step 214: lat: 58.75, lon: -76.83, alt: 8.04
# Step 215: lat: 58.84, lon: -76.85, alt: 8.05
# Step 216: lat: 58.93, lon: -76.88, alt: 8.06
# Step 217: lat: 59.02, lon: -76.90, alt: 8.08
# Step 218: lat: 59.12, lon: -76.93, alt: 8.09
# Step 219: lat: 59.21, lon: -76.95, alt: 8.10
# Step 220: lat: 59.30, lon: -76.98, alt: 8.11
# Step 221: lat: 59.40, lon: -77.00, alt: 8.11
# Step 222: lat: 59.49, lon: -77.03, alt: 8.12
# Step 223: lat: 59.58, lon: -77.06, alt: 8.13
# Step 224: lat: 59.68, lon: -77.08, alt: 8.13
# Step 225: lat: 59.77, lon: -77.11, alt: 8.14
# Step 226: lat: 59.87, lon: -77.14, alt: 8.15
# Step 227: lat: 59.97, lon: -77.17, alt: 8.15
# Step 228: lat: 60.06, lon: -77.19, alt: 8.16
# Step 229: lat: 60.16, lon: -77.22, alt: 8.16
# Step 230: lat: 60.26, lon: -77.25, alt: 8.16
# Step 231: lat: 60.36, lon: -77.28, alt: 8.18
# Step 232: lat: 60.45, lon: -77.31, alt: 8.19
# Step 233: lat: 60.55, lon: -77.34, alt: 8.20
# Step 234: lat: 60.65, lon: -77.37, alt: 8.21
# Step 235: lat: 60.74, lon: -77.40, alt: 8.23
# Step 236: lat: 60.84, lon: -77.43, alt: 8.24
# Step 237: lat: 60.94, lon: -77.47, alt: 8.25
# Step 238: lat: 61.04, lon: -77.50, alt: 8.26
# Step 239: lat: 61.13, lon: -77.53, alt: 8.28
# Step 240: lat: 61.23, lon: -77.56, alt: 8.29
# Step 241: lat: 61.33, lon: -77.59, alt: 8.30
# Step 242: lat: 61.42, lon: -77.62, alt: 8.31
# Step 243: lat: 61.52, lon: -77.66, alt: 8.32
# Step 244: lat: 61.62, lon: -77.69, alt: 8.32
# Step 245: lat: 61.71, lon: -77.72, alt: 8.32
# Step 246: lat: 61.81, lon: -77.75, alt: 8.32
# Step 247: lat: 61.91, lon: -77.79, alt: 8.32
# Step 248: lat: 62.00, lon: -77.82, alt: 8.32
# Step 249: lat: 62.10, lon: -77.85, alt: 8.33
# Step 250: lat: 62.19, lon: -77.88, alt: 8.33
# Step 251: lat: 62.29, lon: -77.92, alt: 8.33
# Step 252: lat: 62.38, lon: -77.95, alt: 8.32
# Step 253: lat: 62.48, lon: -77.98, alt: 8.32
# Step 254: lat: 62.57, lon: -78.02, alt: 8.31
# Step 255: lat: 62.67, lon: -78.05, alt: 8.31
# Step 256: lat: 62.76, lon: -78.08, alt: 8.30
# Step 257: lat: 62.85, lon: -78.11, alt: 8.31
# Step 258: lat: 62.95, lon: -78.15, alt: 8.32
# Step 259: lat: 63.05, lon: -78.18, alt: 8.33
# Step 260: lat: 63.14, lon: -78.21, alt: 8.33
# Step 261: lat: 63.24, lon: -78.24, alt: 8.33
# Step 262: lat: 63.33, lon: -78.28, alt: 8.33
# Step 263: lat: 63.43, lon: -78.31, alt: 8.32
# Step 264: lat: 63.53, lon: -78.34, alt: 8.32
# Step 265: lat: 63.63, lon: -78.38, alt: 8.31
# Step 266: lat: 63.73, lon: -78.41, alt: 8.30
# Step 267: lat: 63.83, lon: -78.44, alt: 8.31
# Step 268: lat: 63.93, lon: -78.48, alt: 8.31
# Step 269: lat: 64.04, lon: -78.51, alt: 8.31
# Step 270: lat: 64.14, lon: -78.54, alt: 8.32
# Step 271: lat: 64.24, lon: -78.58, alt: 8.33
# Step 272: lat: 64.35, lon: -78.61, alt: 8.33
# Step 273: lat: 64.45, lon: -78.64, alt: 8.33
# Step 274: lat: 64.56, lon: -78.68, alt: 8.33
# Step 275: lat: 64.66, lon: -78.71, alt: 8.33
# Step 276: lat: 64.76, lon: -78.74, alt: 8.33
# Step 277: lat: 64.86, lon: -78.78, alt: 8.33
# Step 278: lat: 64.97, lon: -78.81, alt: 8.33
# Step 279: lat: 65.07, lon: -78.84, alt: 8.33
# Step 280: lat: 65.16, lon: -78.88, alt: 8.33
# Step 281: lat: 65.26, lon: -78.91, alt: 8.33
# Step 282: lat: 65.35, lon: -78.94, alt: 8.33
# Step 283: lat: 65.45, lon: -78.98, alt: 8.33
# Step 284: lat: 65.54, lon: -79.01, alt: 8.33
# Step 285: lat: 65.62, lon: -79.04, alt: 8.32
# Step 286: lat: 65.71, lon: -79.08, alt: 8.32
# Step 287: lat: 65.79, lon: -79.11, alt: 8.32
# Step 288: lat: 65.88, lon: -79.14, alt: 8.32
# Step 289: lat: 65.96, lon: -79.17, alt: 8.32
# Step 290: lat: 66.03, lon: -79.21, alt: 8.32
# Step 291: lat: 66.11, lon: -79.24, alt: 8.33
# Step 292: lat: 66.18, lon: -79.27, alt: 8.33
# Step 293: lat: 66.25, lon: -79.31, alt: 8.33
# Step 294: lat: 66.32, lon: -79.34, alt: 8.33
# Step 295: lat: 66.38, lon: -79.37, alt: 8.33
# Step 296: lat: 66.45, lon: -79.41, alt: 8.33
# Step 297: lat: 66.51, lon: -79.44, alt: 8.33
# Step 298: lat: 66.57, lon: -79.47, alt: 8.32
# Step 299: lat: 66.63, lon: -79.51, alt: 8.33
# Step 300: lat: 66.68, lon: -79.54, alt: 8.33
# Step 301: lat: 66.74, lon: -79.57, alt: 8.33
# Step 302: lat: 66.79, lon: -79.61, alt: 8.33
# Step 303: lat: 66.84, lon: -79.64, alt: 8.32
# Step 304: lat: 66.89, lon: -79.68, alt: 8.32
# Step 305: lat: 66.94, lon: -79.71, alt: 8.33
# Step 306: lat: 66.99, lon: -79.74, alt: 8.33
# Step 307: lat: 67.04, lon: -79.78, alt: 8.32
# Step 308: lat: 67.08, lon: -79.81, alt: 8.32
# Step 309: lat: 67.13, lon: -79.84, alt: 8.32
# Step 310: lat: 67.17, lon: -79.88, alt: 8.32
# Step 311: lat: 67.21, lon: -79.91, alt: 8.32
# Step 312: lat: 67.26, lon: -79.95, alt: 8.32
# Step 313: lat: 67.30, lon: -79.98, alt: 8.31
# Step 314: lat: 67.34, lon: -80.01, alt: 8.30
# Step 315: lat: 67.38, lon: -80.05, alt: 8.29
# Step 316: lat: 67.42, lon: -80.08, alt: 8.29
# Step 317: lat: 67.46, lon: -80.11, alt: 8.28
# Step 318: lat: 67.49, lon: -80.14, alt: 8.28
# Step 319: lat: 67.53, lon: -80.18, alt: 8.28
# Step 320: lat: 67.57, lon: -80.21, alt: 8.28
# Step 321: lat: 67.60, lon: -80.24, alt: 8.27
# Step 322: lat: 67.64, lon: -80.27, alt: 8.27
# Step 323: lat: 67.68, lon: -80.31, alt: 8.27
# Step 324: lat: 67.71, lon: -80.34, alt: 8.27
# Step 325: lat: 67.74, lon: -80.37, alt: 8.27
# Step 326: lat: 67.78, lon: -80.40, alt: 8.26
# Step 327: lat: 67.81, lon: -80.43, alt: 8.25
# Step 328: lat: 67.85, lon: -80.46, alt: 8.25
# Step 329: lat: 67.88, lon: -80.49, alt: 8.24
# Step 330: lat: 67.91, lon: -80.52, alt: 8.24
# Step 331: lat: 67.94, lon: -80.55, alt: 8.23
# Step 332: lat: 67.98, lon: -80.58, alt: 8.23
# Step 333: lat: 68.01, lon: -80.61, alt: 8.23
# Step 334: lat: 68.04, lon: -80.64, alt: 8.23
# Step 335: lat: 68.07, lon: -80.67, alt: 8.22
# Step 336: lat: 68.10, lon: -80.70, alt: 8.21
# ...
# Step 427: lat: 73.93, lon: -82.52, alt: 8.32
# Step 428: lat: 74.06, lon: -82.52, alt: 8.32
# Step 429: lat: 74.19, lon: -82.53, alt: 8.32
# Step 430: lat: 74.32, lon: -82.54, alt: 8.32
# Step 431: lat: 74.44, lon: -82.54, alt: 8.33
# Step 432: lat: 74.56, lon: -82.55, alt: 8.33
# Step 433: lat: 74.68, lon: -82.55, alt: 8.33
# Step 434: lat: 74.80, lon: -82.55, alt: 8.34
# Step 435: lat: 74.91, lon: -82.56, alt: 8.34
# Step 436: lat: 75.01, lon: -82.56, alt: 8.34
# Step 437: lat: 75.12, lon: -82.56, alt: 8.34
# Step 438: lat: 75.22, lon: -82.56, alt: 8.33
# Step 439: lat: 75.32, lon: -82.56, alt: 8.32
# Step 440: lat: 75.41, lon: -82.56, alt: 8.32
# Step 441: lat: 75.50, lon: -82.56, alt: 8.32
# Step 442: lat: 75.59, lon: -82.56, alt: 8.31
# Step 443: lat: 75.68, lon: -82.56, alt: 8.31
# Step 444: lat: 75.76, lon: -82.56, alt: 8.31
# Step 445: lat: 75.83, lon: -82.56, alt: 8.31
# Step 446: lat: 75.90, lon: -82.56, alt: 8.32
# Step 447: lat: 75.97, lon: -82.56, alt: 8.32
# Step 448: lat: 76.04, lon: -82.55, alt: 8.32
# Step 449: lat: 76.10, lon: -82.55, alt: 8.32
# Step 450: lat: 76.16, lon: -82.55, alt: 8.32
# Step 451: lat: 76.22, lon: -82.54, alt: 8.33
# Step 452: lat: 76.27, lon: -82.54, alt: 8.33
# Step 453: lat: 76.32, lon: -82.54, alt: 8.33
# Step 454: lat: 76.37, lon: -82.53, alt: 8.34
# Step 455: lat: 76.42, lon: -82.53, alt: 8.33
# Step 456: lat: 76.46, lon: -82.52, alt: 8.33
# Step 457: lat: 76.51, lon: -82.52, alt: 8.33
# Step 458: lat: 76.55, lon: -82.51, alt: 8.33
# Step 459: lat: 76.59, lon: -82.51, alt: 8.33
# Step 460: lat: 76.63, lon: -82.50, alt: 8.33
# Step 461: lat: 76.66, lon: -82.50, alt: 8.33
# Step 462: lat: 76.70, lon: -82.49, alt: 8.32
# Step 463: lat: 76.73, lon: -82.49, alt: 8.32
# Step 464: lat: 76.76, lon: -82.48, alt: 8.32
# Step 465: lat: 76.79, lon: -82.48, alt: 8.32
# Step 466: lat: 76.82, lon: -82.47, alt: 8.32
# Step 467: lat: 76.85, lon: -82.47, alt: 8.33
# Step 468: lat: 76.87, lon: -82.46, alt: 8.33
# Step 469: lat: 76.90, lon: -82.45, alt: 8.32
# Step 470: lat: 76.92, lon: -82.45, alt: 8.32
# Step 471: lat: 76.94, lon: -82.44, alt: 8.32
# Step 472: lat: 76.96, lon: -82.43, alt: 8.32
# Step 473: lat: 76.98, lon: -82.43, alt: 8.32
# Step 474: lat: 77.00, lon: -82.42, alt: 8.32
# Step 475: lat: 77.02, lon: -82.41, alt: 8.32
# Step 476: lat: 77.04, lon: -82.41, alt: 8.32
# Step 477: lat: 77.05, lon: -82.40, alt: 8.32
# Step 478: lat: 77.07, lon: -82.39, alt: 8.32
# Step 479: lat: 77.08, lon: -82.39, alt: 8.32
# Step 480: lat: 77.10, lon: -82.38, alt: 8.32
# Step 481: lat: 77.11, lon: -82.37, alt: 8.32
# Step 482: lat: 77.12, lon: -82.37, alt: 8.32
# Step 483: lat: 77.13, lon: -82.36, alt: 8.32
# Step 484: lat: 77.15, lon: -82.35, alt: 8.31
# Step 485: lat: 77.16, lon: -82.35, alt: 8.31
# Step 486: lat: 77.17, lon: -82.34, alt: 8.30
# Step 487: lat: 77.17, lon: -82.33, alt: 8.30
# Step 488: lat: 77.18, lon: -82.32, alt: 8.30
# Step 489: lat: 77.19, lon: -82.32, alt: 8.30
# Step 490: lat: 77.20, lon: -82.31, alt: 8.31
# Step 491: lat: 77.21, lon: -82.30, alt: 8.32
# Step 492: lat: 77.21, lon: -82.29, alt: 8.32
# Step 493: lat: 77.22, lon: -82.29, alt: 8.33
# Step 494: lat: 77.22, lon: -82.28, alt: 8.33
# Step 495: lat: 77.23, lon: -82.27, alt: 8.34
# Step 496: lat: 77.24, lon: -82.27, alt: 8.34
# Step 497: lat: 77.24, lon: -82.26, alt: 8.34
# Step 498: lat: 77.25, lon: -82.25, alt: 8.34
# Step 499: lat: 77.25, lon: -82.24, alt: 8.34
# Step 500: lat: 77.25, lon: -82.24, alt: 8.35
# Step 501: lat: 77.26, lon: -82.23, alt: 8.36
# Step 502: lat: 77.26, lon: -82.22, alt: 8.36
# Step 503: lat: 77.26, lon: -82.21, alt: 8.36
# Step 504: lat: 77.27, lon: -82.21, alt: 8.36
# Step 505: lat: 77.27, lon: -82.20, alt: 8.37
# Step 506: lat: 77.27, lon: -82.19, alt: 8.37
# Step 507: lat: 77.27, lon: -82.18, alt: 8.37
# Step 508: lat: 77.27, lon: -82.18, alt: 8.38
# Step 509: lat: 77.28, lon: -82.17, alt: 8.39
# Step 510: lat: 77.28, lon: -82.16, alt: 8.40
# Step 511: lat: 77.28, lon: -82.15, alt: 8.42
# Step 512: lat: 77.28, lon: -82.14, alt: 8.43
# Step 513: lat: 77.28, lon: -82.14, alt: 8.45
# Step 514: lat: 77.28, lon: -82.13, alt: 8.47
# Step 515: lat: 77.28, lon: -82.12, alt: 8.49
# Step 516: lat: 77.27, lon: -82.11, alt: 8.50
# Step 517: lat: 77.27, lon: -82.11, alt: 8.51
# Step 518: lat: 77.27, lon: -82.10, alt: 8.52
# Step 519: lat: 77.27, lon: -82.09, alt: 8.53
# Step 520: lat: 77.27, lon: -82.08, alt: 8.54
# Step 521: lat: 77.27, lon: -82.08, alt: 8.56
# Step 522: lat: 77.26, lon: -82.07, alt: 8.57
# Step 523: lat: 77.26, lon: -82.06, alt: 8.58
# Step 524: lat: 77.26, lon: -82.05, alt: 8.59
# Step 525: lat: 77.26, lon: -82.05, alt: 8.60
# Step 526: lat: 77.25, lon: -82.04, alt: 8.61
# Step 527: lat: 77.25, lon: -82.03, alt: 8.61
# Step 528: lat: 77.25, lon: -82.02, alt: 8.61
# Step 529: lat: 77.25, lon: -82.02, alt: 8.60
# Step 530: lat: 77.24, lon: -82.01, alt: 8.60
# Step 531: lat: 77.24, lon: -82.00, alt: 8.59
# Step 532: lat: 77.24, lon: -81.99, alt: 8.59
# Step 533: lat: 77.24, lon: -81.99, alt: 8.58
# Step 534: lat: 77.24, lon: -81.98, alt: 8.57
# Step 535: lat: 77.23, lon: -81.97, alt: 8.56
# Step 536: lat: 77.23, lon: -81.96, alt: 8.55
# Step 537: lat: 77.23, lon: -81.96, alt: 8.53
# Step 538: lat: 77.23, lon: -81.95, alt: 8.51
# Step 539: lat: 77.23, lon: -81.94, alt: 8.49
# Step 540: lat: 77.23, lon: -81.93, alt: 8.47
# Step 541: lat: 77.23, lon: -81.93, alt: 8.45
# Step 542: lat: 77.24, lon: -81.92, alt: 8.43
# Step 543: lat: 77.24, lon: -81.91, alt: 8.41
# Step 544: lat: 77.24, lon: -81.90, alt: 8.39
# Step 545: lat: 77.24, lon: -81.90, alt: 8.37
# Step 546: lat: 77.24, lon: -81.89, alt: 8.35
# Step 547: lat: 77.25, lon: -81.88, alt: 8.34
# Step 548: lat: 77.25, lon: -81.88, alt: 8.33
# Step 549: lat: 77.25, lon: -81.87, alt: 8.32
# Step 550: lat: 77.25, lon: -81.86, alt: 8.31
# Step 551: lat: 77.26, lon: -81.85, alt: 8.31
# Step 552: lat: 77.26, lon: -81.85, alt: 8.31
# Step 553: lat: 77.26, lon: -81.84, alt: 8.31
# Step 554: lat: 77.26, lon: -81.83, alt: 8.32
# Step 555: lat: 77.26, lon: -81.82, alt: 8.32
# Step 556: lat: 77.26, lon: -81.82, alt: 8.33
# Step 557: lat: 77.26, lon: -81.81, alt: 8.33
# Step 558: lat: 77.27, lon: -81.80, alt: 8.34
# Step 559: lat: 77.27, lon: -81.79, alt: 8.35
# Step 560: lat: 77.27, lon: -81.79, alt: 8.37
# Step 561: lat: 77.27, lon: -81.78, alt: 8.37
# Step 562: lat: 77.27, lon: -81.77, alt: 8.39
# Step 563: lat: 77.27, lon: -81.76, alt: 8.40
# Step 564: lat: 77.26, lon: -81.76, alt: 8.40
# Step 565: lat: 77.26, lon: -81.75, alt: 8.41
# Step 566: lat: 77.26, lon: -81.74, alt: 8.41
# Step 567: lat: 77.26, lon: -81.73, alt: 8.42
# Step 568: lat: 77.26, lon: -81.73, alt: 8.42
# Step 569: lat: 77.26, lon: -81.72, alt: 8.42
# Step 570: lat: 77.26, lon: -81.71, alt: 8.42
# Step 571: lat: 77.25, lon: -81.70, alt: 8.42
# Step 572: lat: 77.25, lon: -81.70, alt: 8.41
# Step 573: lat: 77.25, lon: -81.69, alt: 8.41
# Step 574: lat: 77.25, lon: -81.68, alt: 8.41
# Step 575: lat: 77.25, lon: -81.67, alt: 8.40
# Step 576: lat: 77.25, lon: -81.67, alt: 8.40
# Step 577: lat: 77.24, lon: -81.66, alt: 8.39
# Step 578: lat: 77.24, lon: -81.65, alt: 8.39
# Step 579: lat: 77.24, lon: -81.65, alt: 8.38
# Step 580: lat: 77.24, lon: -81.64, alt: 8.36
# Step 581: lat: 77.24, lon: -81.63, alt: 8.35
# Step 582: lat: 77.24, lon: -81.62, alt: 8.34
# Step 583: lat: 77.24, lon: -81.62, alt: 8.33
# Step 584: lat: 77.24, lon: -81.61, alt: 8.32
# Step 585: lat: 77.24, lon: -81.60, alt: 8.31
# Step 586: lat: 77.24, lon: -81.59, alt: 8.31
# Step 587: lat: 77.24, lon: -81.59, alt: 8.30
# Step 588: lat: 77.23, lon: -81.58, alt: 8.30
# Step 589: lat: 77.23, lon: -81.57, alt: 8.30
# Step 590: lat: 77.23, lon: -81.56, alt: 8.30
# Step 591: lat: 77.23, lon: -81.56, alt: 8.30
# Step 592: lat: 77.23, lon: -81.55, alt: 8.30
# Step 593: lat: 77.23, lon: -81.54, alt: 8.31
# Step 594: lat: 77.23, lon: -81.53, alt: 8.31
# Step 595: lat: 77.23, lon: -81.53, alt: 8.32
# Step 596: lat: 77.23, lon: -81.52, alt: 8.32
# Step 597: lat: 77.23, lon: -81.51, alt: 8.32
# Step 598: lat: 77.22, lon: -81.51, alt: 8.32
# Step 599: lat: 77.22, lon: -81.50, alt: 8.33
# Step 600: lat: 77.22, lon: -81.49, alt: 8.34
# Step 601: lat: 77.22, lon: -81.48, alt: 8.35
# Step 602: lat: 77.22, lon: -81.48, alt: 8.35
# Step 603: lat: 77.22, lon: -81.47, alt: 8.35
# Step 604: lat: 77.22, lon: -81.46, alt: 8.35
# Step 605: lat: 77.22, lon: -81.45, alt: 8.34
# Step 606: lat: 77.21, lon: -81.45, alt: 8.33
# Step 607: lat: 77.21, lon: -81.44, alt: 8.33
# Step 608: lat: 77.21, lon: -81.43, alt: 8.32
# Step 609: lat: 77.21, lon: -81.43, alt: 8.31
# Step 610: lat: 77.21, lon: -81.42, alt: 8.32
# Step 611: lat: 77.21, lon: -81.41, alt: 8.32
# Step 612: lat: 77.21, lon: -81.40, alt: 8.33
# Step 613: lat: 77.21, lon: -81.40, alt: 8.34
# Step 614: lat: 77.21, lon: -81.39, alt: 8.34
# Step 615: lat: 77.21, lon: -81.38, alt: 8.33
# Step 616: lat: 77.21, lon: -81.37, alt: 8.32
# Step 617: lat: 77.21, lon: -81.37, alt: 8.32
# Step 618: lat: 77.21, lon: -81.36, alt: 8.32
# Step 619: lat: 77.21, lon: -81.35, alt: 8.32
# Step 620: lat: 77.21, lon: -81.35, alt: 8.32
# Step 621: lat: 77.20, lon: -81.34, alt: 8.32
# Step 622: lat: 77.20, lon: -81.33, alt: 8.33
# Step 623: lat: 77.20, lon: -81.32, alt: 8.33
# Step 624: lat: 77.20, lon: -81.32, alt: 8.34
# Step 625: lat: 77.20, lon: -81.31, alt: 8.34
# Step 626: lat: 77.20, lon: -81.30, alt: 8.34
# Step 627: lat: 77.20, lon: -81.29, alt: 8.34
# Step 628: lat: 77.20, lon: -81.29, alt: 8.33
# Step 629: lat: 77.20, lon: -81.28, alt: 8.32
# Step 630: lat: 77.20, lon: -81.27, alt: 8.32
# Step 631: lat: 77.20, lon: -81.27, alt: 8.32
# Step 632: lat: 77.20, lon: -81.26, alt: 8.32
# Step 633: lat: 77.20, lon: -81.25, alt: 8.32
# Step 634: lat: 77.20, lon: -81.24, alt: 8.32
# Step 635: lat: 77.20, lon: -81.24, alt: 8.32
# Step 636: lat: 77.20, lon: -81.23, alt: 8.31
# Step 637: lat: 77.21, lon: -81.22, alt: 8.32
# Step 638: lat: 77.21, lon: -81.21, alt: 8.31
# Step 639: lat: 77.21, lon: -81.21, alt: 8.31
# Step 640: lat: 77.21, lon: -81.20, alt: 8.31
# Step 641: lat: 77.21, lon: -81.19, alt: 8.31
# Step 642: lat: 77.21, lon: -81.19, alt: 8.32
# Step 643: lat: 77.21, lon: -81.18, alt: 8.32
# Step 644: lat: 77.22, lon: -81.17, alt: 8.32
# Step 645: lat: 77.22, lon: -81.16, alt: 8.32
# Step 646: lat: 77.22, lon: -81.16, alt: 8.32
# Step 647: lat: 77.22, lon: -81.15, alt: 8.32
# Step 648: lat: 77.22, lon: -81.14, alt: 8.32
# Step 649: lat: 77.23, lon: -81.13, alt: 8.32
# Step 650: lat: 77.23, lon: -81.13, alt: 8.33
# Step 651: lat: 77.23, lon: -81.12, alt: 8.33
# Step 652: lat: 77.23, lon: -81.11, alt: 8.33
# Step 653: lat: 77.23, lon: -81.11, alt: 8.33
# Step 654: lat: 77.24, lon: -81.10, alt: 8.33
# Step 655: lat: 77.24, lon: -81.09, alt: 8.33
# Step 656: lat: 77.24, lon: -81.08, alt: 8.33
# Step 657: lat: 77.25, lon: -81.08, alt: 8.33
# Step 658: lat: 77.25, lon: -81.07, alt: 8.33
# Step 659: lat: 77.25, lon: -81.06, alt: 8.32
# Step 660: lat: 77.25, lon: -81.06, alt: 8.32
# Step 661: lat: 77.26, lon: -81.05, alt: 8.32
# Step 662: lat: 77.26, lon: -81.04, alt: 8.32
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 8
#       6 num_iter = 3
#       7 for i in range(num_iter):
# ----> 8     expert_total_reward, expert_states_np, expert_actions_np = run_expert_episode(env, expert, max_steps=max_steps, policy_name=f'expert_{i+1}')
#       9     expert_total_reward_list.append(expert_total_reward)
#      10     expert_states_list.append(expert_states_np)
#
# Cell In[9], line 30, in run_expert_episode(env, agent, max_steps, policy_name)
#      27 sands = []
#      28 for step in range(max_steps):
#      29     # Get action from agent
# ---> 30     action = agent.select_action(state, env, step)
#      32     # record state and expert action
#      33     initial_states.append(state)
#
# File ~\Documents\balloon-outreach\agent\mppi_agent.py:77, in MPPIAgent.select_action(self, state, env, step_num)
#      75 start_time = time.time()
#      76 for i in range(self.num_samples):
# ---> 77     cost, trajectory = self._evaluate_control_sequence(acc_samples[i], vel_samples[i], state, env)
#      78     # clean_traj = [
#      79     #     (round(float(lat), 2), round(float(lon), 2), round(float(alt), 2))
#      80     #     for lat, lon, alt in trajectory
#      81     # ]
#      82     clean_traj = [
#      83         round(float(vel), 2)
#      84         for vel in vel_samples[i]
#      85     ]
#
# File ~\Documents\balloon-outreach\agent\mppi_agent.py:301, in MPPIAgentWithCostFunction._evaluate_control_sequence(self, acc_seq, vel_seq, initial_state, env, visualize)
#     299     initial_goal_cost = np.sqrt(lat_diff**2 + lon_diff**2)
#     300     # return env.rollout_sequence_mppi_with_cost(vel_seq, acc_seq, min(self.horizon, len(vel_seq)), self._compute_step_cost_target, target_state, initial_goal_cost)
# --> 301     return env.rollout_sequence_mppi_with_cost(vel_seq, acc_seq, min(self.horizon, len(vel_seq)), self._compute_step_cost_target2, target_state, initial_goal_cost)
#     302 else:
#     303     # cost, trajectory = env.rollout_sequence_mppi_with_cost(vel_seq, acc_seq, min(self.horizon, len(vel_seq)), self._compute_step_cost_fly, env.init_state)
#     304     cost, trajectory = env.rollout_sequence_mppi_with_cost(vel_seq, acc_seq, min(self.horizon, len(vel_seq)), self._compute_step_cost_fly2, env.init_state)
#
# File ~\Documents\balloon-outreach\env\balloon_env.py:236, in BaseBalloonEnvironment.rollout_sequence_mppi_with_cost(self, vel_seq, acc_seq, max_steps, cost_fcn, *params)
#     233 acc = np.array([acc_seq[t]])
#     234 # Take step in environment
#     235 # next_state, _, done, _ = self.step(action)
# --> 236 next_state, _, done, _ = self.simplified_step(action)
#     238 trajectory.append((next_state[0], next_state[1], next_state[2]))
#     239 # Custom cost function
#
# File ~\Documents\balloon-outreach\env\balloon_env.py:91, in BaseBalloonEnvironment.simplified_step(self, action)
#      89 self.balloon.simplified_step(wind, self.dt, action_value)
#      90 self.current_time += self.dt / 3600
# ---> 91 state = self._get_state()
#      92 reward = self._get_reward()
#      93 done, reason = self._is_done()
#
# File ~\Documents\balloon-outreach\env\balloon_env.py:123, in BaseBalloonEnvironment._get_state(self)
#     121 def _get_state(self) -> np.ndarray:
#     122     balloon_state = self._get_balloon_state()
# --> 123     wind_column = self._get_wind_column()
#     124     return np.concatenate([balloon_state, wind_column])
#
# File ~\Documents\balloon-outreach\env\balloon_env.py:128, in BaseBalloonEnvironment._get_wind_column(self)
#     126 wind_column = []
#     127 for pressure in self.wind_field.pressure_levels:
# --> 128     wind = self.wind_field.get_wind(
#     129         self.balloon.lon,
#     130         self.balloon.lat,
#     131         pressure,
#     132         self.current_time
#     133     )
#     134     wind_column.extend([wind.u, wind.v])
#     135 return np.array(wind_column)
#
# File ~\Documents\balloon-outreach\env\ERA_wind_field.py:90, in WindField.get_wind(self, lon, lat, pressure, elapsed_time)
#      88 pt = np.array([elapsed_time, pressure, lat, lon], dtype=float)
#      89 u0 = float(self._u_interp(pt))
# ---> 90 v0 = float(self._v_interp(pt))
#      92 if not self.add_noise:
#      93     # noise turned off
#      94     return WindVector(u=u0, v=v0)
#
# File c:\Users\sc3377\AppData\Local\anaconda3\envs\balloon\Lib\site-packages\scipy\interpolate\_rgi.py:423, in RegularGridInterpolator.__call__(self, xi, method, nu)
#     417         result = evaluate_linear_2d(self.values,
#     418                                     indices,
#     419                                     norm_distances,
#     420                                     self.grid,
#     421                                     out)
#     422     else:
# --> 423         result = self._evaluate_linear(indices, norm_distances)
#     424 elif method == "nearest":
#     425     indices, norm_distances = self._find_indices(xi.T)
#
# File c:\Users\sc3377\AppData\Local\anaconda3\envs\balloon\Lib\site-packages\scipy\interpolate\_rgi.py:497, in RegularGridInterpolator._evaluate_linear(self, indices, norm_distances)
#     495     for w in weights:
#     496         weight = weight * w
# --> 497     term = np.asarray(self.values[edge_indices]) * weight[vslice]
#     498     value = value + term   # cannot use += because broadcasting
#     499 return value
#
# KeyboardInterrupt:

# %%
print(expert_total_reward_list)
expert_avg_total_reward = sum(expert_total_reward_list)/len(expert_total_reward_list)
print(f"Expert Trajectory reward in average: {expert_avg_total_reward:.2f}")

# %%
expert_states_np = np.concatenate(expert_states_list)
expert_actions_np = np.concatenate(expert_actions_list)

# %% [markdown]
# ## Define our policy network

# %%
class PolicyNet(nn.Module):
    def __init__(self, input_dim=21, hidden_dim=64, output_dim=1):
        super(PolicyNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim*2)
        self.ln1 = nn.LayerNorm(hidden_dim*2)
        self.fc2 = nn.Linear(hidden_dim*2, hidden_dim)
        self.ln2 = nn.LayerNorm(hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, output_dim)

        # Weight initialization
        nn.init.kaiming_uniform_(self.fc1.weight, nonlinearity='relu')
        nn.init.zeros_(self.fc1.bias)
        nn.init.kaiming_uniform_(self.fc2.weight, nonlinearity='relu')
        nn.init.zeros_(self.fc2.bias)
        nn.init.xavier_uniform_(self.fc3.weight, gain=nn.init.calculate_gain('tanh'))
        nn.init.zeros_(self.fc3.bias)

    def forward(self, x):
        # x shape: (batch_size, input_dim)
        x = self.fc1(x)
        x = self.ln1(x)
        x = F.relu(x)
        x = self.fc2(x)
        x = self.ln2(x)
        x = F.relu(x)
        x = self.fc3(x)
        return F.tanh(x)

# Initialize policy network and optimizer
policy = PolicyNet()
optimizer = optim.Adam(policy.parameters(), lr=1e-3)
loss_fn = nn.MSELoss()

# %%
# Evaluate a policy on the environment
def evaluate_policy(env: BalloonERAEnvironment,
                    policy: nn.Module,
                    max_steps: int,
                    policy_name: str,
                    expert_avg_total_reward: float):
    policy.eval()
    if policy.training:
        print("→ policy is in training mode")
    else:
        print("→ policy is in evaluation mode")

    state = env.reset()
    total_reward = 0.0

    # Store trajectory for plotting
    trajectory = [(state[0], state[1])]  # (lat, lon) pairs
    altitudes = [state[2]]  # Store altitudes

    actions = []
    velocities = []
    helium_mass = []
    sands = []

    for step in range(max_steps):
        state_tensor = torch.from_numpy(state).float().unsqueeze(0)      # shape (1, 21)
        action_pred = policy(state_tensor).item()                        # continuous action
        state, reward, done, info = env.step(action_pred)
        total_reward += reward

        actions.append(float(action_pred) if isinstance(action_pred, np.ndarray) else float(action_pred))
        velocities.append(env.balloon.vertical_velocity)
        helium_mass.append(env.balloon.helium_mass)
        sands.append(env.balloon.sand)

        # Store position and altitude
        trajectory.append((state[0], state[1]))
        altitudes.append(state[2])

        if done:
            print(f"\nEpisode terminated: {info}")
            break
    print(f"Total reward obtained from current policy: {total_reward:.2f}")
    print(f"Expert policy reward - Current policy reward: {expert_avg_total_reward-total_reward:.2f}")

    # Plot final trajectory
    plot_agent_trajectory(trajectory=trajectory,
                          altitudes=altitudes,
                          actions=actions,
                          velocities=velocities,
                          helium_mass=helium_mass,
                          sands=sands,
                          policy_name=policy_name,
                          max_steps=max_steps,
                          dt=env.dt,
                          objective='target',
                          target_lon=env.target_lon,
                          target_lat=env.target_lat,
                          target_alt=env.target_alt
                          )

    return total_reward

# %%
env.wind_field.disable_noise()
# env.wind_field.enable_noise(noise_seed=10) # If you want to enable noisy wind field
evaluate_policy(env, policy, max_steps=max_steps, policy_name='random_policy_noiseless', expert_avg_total_reward=expert_avg_total_reward)

# %% [markdown]
# ## Behavior Cloning (Supervised Learning)

# %%
# === Initial Dataset & DataLoader Construction ===

# Convert to tensors
states_tensor = torch.from_numpy(expert_states_np).float()               # shape (N, 21)
actions_tensor = torch.from_numpy(expert_actions_np).float()             # shape (N, 1)

# Construct TensorDataset and DataLoader
dataset = TensorDataset(states_tensor, actions_tensor)
loader = DataLoader(dataset, batch_size=64, shuffle=True)

# %%
# === Training Function Using Loader ===
def train_one_epoch(loader, policy, optimizer, loss_fn):
    policy.train()
    if policy.training:
        print("→ policy is in training mode")
    else:
        print("→ policy is in evaluation mode")

    total_loss = 0.0
    for x_batch, y_batch in loader:
        optimizer.zero_grad()
        preds = policy(x_batch)
        loss = loss_fn(preds, y_batch)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * x_batch.size(0)
    avg_loss = total_loss / len(loader.dataset)
    return avg_loss

# %%
losses = []
for epoch in range(10):
    avg_loss = train_one_epoch(loader, policy, optimizer, loss_fn)
    losses.append(avg_loss)
    print(f"Epoch {epoch+1}/10 — Avg Loss: {avg_loss:.6f} \n")

# plot the loss curve from behavior cloning
plt.figure(figsize=(6,4))
plt.plot(range(1, len(losses)+1), losses, marker='o')
plt.xlabel('Epoch')
plt.ylabel('Average Training Loss')
plt.title('Behavior Cloning Loss Curve')
plt.grid(True)
plt.show()

# %%
env.wind_field.disable_noise()
# env.wind_field.enable_noise(noise_seed=10) # If you want to enable noisy wind field
evaluate_policy(env, policy, max_steps=max_steps, policy_name='BC_trained_policy_noiseless_wf', expert_avg_total_reward=expert_avg_total_reward)
